# %%
##This notebook is built around using tensorflow as the backend for keras
#!KERAS_BACKEND=tensorflow python -c "from keras import backend"

# %%
from tensorflow.keras import applications
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
import mxnet as mx

from mxnet import gluon, nd
from mxnet import autograd as ag
from mxnet.gluon import nn
from mxnet.gluon.data.vision import transforms

import gluoncv
from gluoncv.model_zoo import get_model
from gluoncv.utils import makedirs, TrainingHistory
from gluoncv.data import transforms as gcv_transforms

# %%
# GENERAL PARAMETERS
IMG_WIDTH, IMG_HEIGHT = 299, 299

train_data_dir = 'Open_I_abd_vs_CXRs/TRAIN' #location of training data
validation_data_dir = 'Open_I_abd_vs_CXRs/VAL' #location of validation data
# number of samples used for determining the samples_per_epoch
nb_train_samples = 65
nb_validation_samples = 10

EPOCHS = 5
BATCH_SIZE = 5

# %%
# TENSORFLOW 
train_datagen = ImageDataGenerator(
        rescale=1./255,            # normalize pixel values to [0,1]
        shear_range=0.2,      
        zoom_range=0.2,    
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True)  


val_datagen = ImageDataGenerator(
         rescale=1./255)       # normalize pixel values to [0,1]

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='binary')

validation_generator = train_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='binary')
# Out:
# Found 65 images belonging to 2 classes.
# Found 10 images belonging to 2 classes.

# %%
#!python3 -m pip uninstall d2l
#help(gluon.data.vision.transforms)

# %%
# MXNET

train_imgs = gluon.data.vision.ImageFolderDataset(train_data_dir)
test_imgs = gluon.data.vision.ImageFolderDataset(validation_data_dir)

train_augs = gluon.data.vision.transforms.Compose([
    gluon.data.vision.transforms.RandomResizedCrop(224),
    gluon.data.vision.transforms.RandomFlipLeftRight(),
    gluon.data.vision.transforms.ToTensor()
])

test_augs = gluon.data.vision.transforms.Compose([
    gluon.data.vision.transforms.Resize(256),
    gluon.data.vision.transforms.CenterCrop(224),
    gluon.data.vision.transforms.ToTensor()
])
'''
transform_train = transforms.Compose([
    gcv_transforms.RandomCrop(32, pad=4),
    transforms.RandomFlipLeftRight(),
    transforms.ToTensor(),
    transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])
])

# Define the data loaders for the training and test dataset.
train_data = gluon.data.DataLoader(
    gluon.data.vision.CIFAR10(train=True).transform_first(
        transform_train),  # set path to the downloaded data
    batch_size=batch_size, shuffle=True, last_batch='discard', num_workers=num_workers)

val_data = gluon.data.DataLoader(
    gluon.data.vision.CIFAR10(train=False).transform_first(transform_test),
    batch_size=batch_size, shuffle=False, num_workers=num_workers)
'''
train_data_mx = gluon.data.DataLoader(
    train_imgs.transform_first(train_augs), BATCH_SIZE, shuffle=True)
#test_iter = gluon.data.DataLoader(
#    test_imgs.transform_first(test_augs), batch_size)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Ignoring Open_I_abd_vs_CXRs/TRAIN/.DS_Store, which is not a directory.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## GPU - Reproducibility

# %%
# MXNET
gpus = mx.test_utils.list_gpus()
ctx =  [mx.gpu()] if gpus else [mx.cpu(0), mx.cpu(1)]
print(ctx)
# Out:
# [cpu(0), cpu(1)]

# %% [markdown]
# ## Get pretrained model

# %%
# TENSORFLOW
base_model = applications.InceptionV3(weights='imagenet', include_top=False, input_shape=(IMG_WIDTH, IMG_HEIGHT, 3))

# %%
# MXNET
net = gluoncv.model_zoo.I3D_InceptionV3(pretrained=True, ctx = ctx, nclass=2)

# %% [markdown]
# ## Attach last layer

# %%
# MXNET
deep_medical_net = gluoncv.model_zoo.I3D_InceptionV3(prefix='deep_medical_', nclass=2)
deep_medical_net.collect_params().initialize(ctx=ctx, force_reinit=True)
deep_medical_net.features = net.features
deep_medical_net.output.initialize(mx.init.Xavier(), force_reinit=True)
deep_medical_net.summary
# Out:
# deep_medical_conv0_weight is done with shape:  (32, 3, 3, 3, 3)
# deep_medical_batchnorm0_gamma is done with shape:  (32,)
# deep_medical_batchnorm0_beta is done with shape:  (32,)
# deep_medical_batchnorm0_running_mean is done with shape:  (32,)
# deep_medical_batchnorm0_running_var is done with shape:  (32,)
# deep_medical_conv1_weight is done with shape:  (32, 32, 3, 3, 3)
# deep_medical_batchnorm1_gamma is done with shape:  (32,)
# deep_medical_batchnorm1_beta is done with shape:  (32,)
# deep_medical_batchnorm1_running_mean is done with shape:  (32,)
# deep_medical_batchnorm1_running_var is done with shape:  (32,)
# deep_medical_conv2_weight is done with shape:  (64, 32, 3, 3, 3)
# deep_medical_batchnorm2_gamma is done with shape:  (64,)
# deep_medical_batchnorm2_beta is done with shape:  (64,)
# deep_medical_batchnorm2_running_mean is done with shape:  (64,)
# deep_medical_batchnorm2_running_var is done with shape:  (64,)
# deep_medical_conv3_weight is done with shape:  (80, 64, 1, 1, 1)
# deep_medical_batchnorm3_gamma is done with shape:  (80,)
# deep_medical_batchnorm3_beta is done with shape:  (80,)
# deep_medical_batchnorm3_running_mean is done with shape:  (80,)
# deep_medical_batchnorm3_running_var is done with shape:  (80,)
# deep_medical_conv4_weight is done with shape:  (192, 80, 3, 3, 3)
# deep_medical_batchnorm4_gamma is done with shape:  (192,)
# deep_medical_batchnorm4_beta is done with shape:  (192,)
# deep_medical_batchnorm4_running_mean is done with shape:  (192,)
# deep_medical_batchnorm4_running_var is done with shape:  (192,)
# deep_medical_A1_conv0_weight is done with shape:  (64, 192, 1, 1, 1)
# deep_medical_A1_batchnorm0_gamma is done with shape:  (64,)
# deep_medical_A1_batchnorm0_beta is done with shape:  (64,)
# deep_medical_A1_batchnorm0_running_mean is done with shape:  (64,)
# deep_medical_A1_batchnorm0_running_var is done with shape:  (64,)
# deep_medical_A1_conv1_weight is done with shape:  (48, 192, 1, 1, 1)
# deep_medical_A1_batchnorm1_gamma is done with shape:  (48,)
# deep_medical_A1_batchnorm1_beta is done with shape:  (48,)
# deep_medical_A1_batchnorm1_running_mean is done with shape:  (48,)
# deep_medical_A1_batchnorm1_running_var is done with shape:  (48,)
# deep_medical_A1_conv2_weight is done with shape:  (64, 48, 5, 5, 5)
# deep_medical_A1_batchnorm2_gamma is done with shape:  (64,)
# deep_medical_A1_batchnorm2_beta is done with shape:  (64,)
# deep_medical_A1_batchnorm2_running_mean is done with shape:  (64,)
# deep_medical_A1_batchnorm2_running_var is done with shape:  (64,)
# deep_medical_A1_conv3_weight is done with shape:  (64, 192, 1, 1, 1)
# deep_medical_A1_batchnorm3_gamma is done with shape:  (64,)
# deep_medical_A1_batchnorm3_beta is done with shape:  (64,)
# deep_medical_A1_batchnorm3_running_mean is done with shape:  (64,)
# deep_medical_A1_batchnorm3_running_var is done with shape:  (64,)
# deep_medical_A1_conv4_weight is done with shape:  (96, 64, 3, 3, 3)
# deep_medical_A1_batchnorm4_gamma is done with shape:  (96,)
# deep_medical_A1_batchnorm4_beta is done with shape:  (96,)
# deep_medical_A1_batchnorm4_running_mean is done with shape:  (96,)
# deep_medical_A1_batchnorm4_running_var is done with shape:  (96,)
# deep_medical_A1_conv5_weight is done with shape:  (96, 96, 3, 3, 3)
# deep_medical_A1_batchnorm5_gamma is done with shape:  (96,)
# deep_medical_A1_batchnorm5_beta is done with shape:  (96,)
# deep_medical_A1_batchnorm5_running_mean is done with shape:  (96,)
# deep_medical_A1_batchnorm5_running_var is done with shape:  (96,)
# deep_medical_A1_conv6_weight is done with shape:  (32, 192, 1, 1, 1)
# deep_medical_A1_batchnorm6_gamma is done with shape:  (32,)
# deep_medical_A1_batchnorm6_beta is done with shape:  (32,)
# deep_medical_A1_batchnorm6_running_mean is done with shape:  (32,)
# deep_medical_A1_batchnorm6_running_var is done with shape:  (32,)
# deep_medical_A2_conv0_weight is done with shape:  (64, 256, 1, 1, 1)
# deep_medical_A2_batchnorm0_gamma is done with shape:  (64,)
# deep_medical_A2_batchnorm0_beta is done with shape:  (64,)
# deep_medical_A2_batchnorm0_running_mean is done with shape:  (64,)
# deep_medical_A2_batchnorm0_running_var is done with shape:  (64,)
# deep_medical_A2_conv1_weight is done with shape:  (48, 256, 1, 1, 1)
# deep_medical_A2_batchnorm1_gamma is done with shape:  (48,)
# deep_medical_A2_batchnorm1_beta is done with shape:  (48,)
# deep_medical_A2_batchnorm1_running_mean is done with shape:  (48,)
# deep_medical_A2_batchnorm1_running_var is done with shape:  (48,)
# deep_medical_A2_conv2_weight is done with shape:  (64, 48, 5, 5, 5)
# deep_medical_A2_batchnorm2_gamma is done with shape:  (64,)
# deep_medical_A2_batchnorm2_beta is done with shape:  (64,)
# deep_medical_A2_batchnorm2_running_mean is done with shape:  (64,)
# deep_medical_A2_batchnorm2_running_var is done with shape:  (64,)
# deep_medical_A2_conv3_weight is done with shape:  (64, 256, 1, 1, 1)
# deep_medical_A2_batchnorm3_gamma is done with shape:  (64,)
# deep_medical_A2_batchnorm3_beta is done with shape:  (64,)
# deep_medical_A2_batchnorm3_running_mean is done with shape:  (64,)
# deep_medical_A2_batchnorm3_running_var is done with shape:  (64,)
# deep_medical_A2_conv4_weight is done with shape:  (96, 64, 3, 3, 3)
# deep_medical_A2_batchnorm4_gamma is done with shape:  (96,)
# deep_medical_A2_batchnorm4_beta is done with shape:  (96,)
# deep_medical_A2_batchnorm4_running_mean is done with shape:  (96,)
# deep_medical_A2_batchnorm4_running_var is done with shape:  (96,)
# deep_medical_A2_conv5_weight is done with shape:  (96, 96, 3, 3, 3)
# deep_medical_A2_batchnorm5_gamma is done with shape:  (96,)
# deep_medical_A2_batchnorm5_beta is done with shape:  (96,)
# deep_medical_A2_batchnorm5_running_mean is done with shape:  (96,)
# deep_medical_A2_batchnorm5_running_var is done with shape:  (96,)
# deep_medical_A2_conv6_weight is done with shape:  (64, 256, 1, 1, 1)
# deep_medical_A2_batchnorm6_gamma is done with shape:  (64,)
# deep_medical_A2_batchnorm6_beta is done with shape:  (64,)
# deep_medical_A2_batchnorm6_running_mean is done with shape:  (64,)
# deep_medical_A2_batchnorm6_running_var is done with shape:  (64,)
# deep_medical_A3_conv0_weight is done with shape:  (64, 288, 1, 1, 1)
# deep_medical_A3_batchnorm0_gamma is done with shape:  (64,)
# deep_medical_A3_batchnorm0_beta is done with shape:  (64,)
# deep_medical_A3_batchnorm0_running_mean is done with shape:  (64,)
# deep_medical_A3_batchnorm0_running_var is done with shape:  (64,)
# deep_medical_A3_conv1_weight is done with shape:  (48, 288, 1, 1, 1)
# deep_medical_A3_batchnorm1_gamma is done with shape:  (48,)
# deep_medical_A3_batchnorm1_beta is done with shape:  (48,)
# deep_medical_A3_batchnorm1_running_mean is done with shape:  (48,)
# deep_medical_A3_batchnorm1_running_var is done with shape:  (48,)
# deep_medical_A3_conv2_weight is done with shape:  (64, 48, 5, 5, 5)
# deep_medical_A3_batchnorm2_gamma is done with shape:  (64,)
# deep_medical_A3_batchnorm2_beta is done with shape:  (64,)
# deep_medical_A3_batchnorm2_running_mean is done with shape:  (64,)
# deep_medical_A3_batchnorm2_running_var is done with shape:  (64,)
# deep_medical_A3_conv3_weight is done with shape:  (64, 288, 1, 1, 1)
# deep_medical_A3_batchnorm3_gamma is done with shape:  (64,)
# deep_medical_A3_batchnorm3_beta is done with shape:  (64,)
# deep_medical_A3_batchnorm3_running_mean is done with shape:  (64,)
# deep_medical_A3_batchnorm3_running_var is done with shape:  (64,)
# deep_medical_A3_conv4_weight is done with shape:  (96, 64, 3, 3, 3)
# deep_medical_A3_batchnorm4_gamma is done with shape:  (96,)
# deep_medical_A3_batchnorm4_beta is done with shape:  (96,)
# deep_medical_A3_batchnorm4_running_mean is done with shape:  (96,)
# deep_medical_A3_batchnorm4_running_var is done with shape:  (96,)
# deep_medical_A3_conv5_weight is done with shape:  (96, 96, 3, 3, 3)
# deep_medical_A3_batchnorm5_gamma is done with shape:  (96,)
# deep_medical_A3_batchnorm5_beta is done with shape:  (96,)
# deep_medical_A3_batchnorm5_running_mean is done with shape:  (96,)
# deep_medical_A3_batchnorm5_running_var is done with shape:  (96,)
# deep_medical_A3_conv6_weight is done with shape:  (64, 288, 1, 1, 1)
# deep_medical_A3_batchnorm6_gamma is done with shape:  (64,)
# deep_medical_A3_batchnorm6_beta is done with shape:  (64,)
# deep_medical_A3_batchnorm6_running_mean is done with shape:  (64,)
# deep_medical_A3_batchnorm6_running_var is done with shape:  (64,)
# deep_medical_B_conv0_weight is done with shape:  (384, 288, 3, 3, 3)
# deep_medical_B_batchnorm0_gamma is done with shape:  (384,)
# deep_medical_B_batchnorm0_beta is done with shape:  (384,)
# deep_medical_B_batchnorm0_running_mean is done with shape:  (384,)
# deep_medical_B_batchnorm0_running_var is done with shape:  (384,)
# deep_medical_B_conv1_weight is done with shape:  (64, 288, 1, 1, 1)
# deep_medical_B_batchnorm1_gamma is done with shape:  (64,)
# deep_medical_B_batchnorm1_beta is done with shape:  (64,)
# deep_medical_B_batchnorm1_running_mean is done with shape:  (64,)
# deep_medical_B_batchnorm1_running_var is done with shape:  (64,)
# deep_medical_B_conv2_weight is done with shape:  (96, 64, 3, 3, 3)
# deep_medical_B_batchnorm2_gamma is done with shape:  (96,)
# deep_medical_B_batchnorm2_beta is done with shape:  (96,)
# deep_medical_B_batchnorm2_running_mean is done with shape:  (96,)
# deep_medical_B_batchnorm2_running_var is done with shape:  (96,)
# deep_medical_B_conv3_weight is done with shape:  (96, 96, 3, 3, 3)
# deep_medical_B_batchnorm3_gamma is done with shape:  (96,)
# deep_medical_B_batchnorm3_beta is done with shape:  (96,)
# deep_medical_B_batchnorm3_running_mean is done with shape:  (96,)
# deep_medical_B_batchnorm3_running_var is done with shape:  (96,)
# deep_medical_C1_conv0_weight is done with shape:  (192, 768, 1, 1, 1)
# deep_medical_C1_batchnorm0_gamma is done with shape:  (192,)
# deep_medical_C1_batchnorm0_beta is done with shape:  (192,)
# deep_medical_C1_batchnorm0_running_mean is done with shape:  (192,)
# deep_medical_C1_batchnorm0_running_var is done with shape:  (192,)
# deep_medical_C1_conv1_weight is done with shape:  (128, 768, 1, 1, 1)
# deep_medical_C1_batchnorm1_gamma is done with shape:  (128,)
# deep_medical_C1_batchnorm1_beta is done with shape:  (128,)
# deep_medical_C1_batchnorm1_running_mean is done with shape:  (128,)
# deep_medical_C1_batchnorm1_running_var is done with shape:  (128,)
# deep_medical_C1_conv2_weight is done with shape:  (128, 128, 7, 1, 7)
# deep_medical_C1_batchnorm2_gamma is done with shape:  (128,)
# deep_medical_C1_batchnorm2_beta is done with shape:  (128,)
# deep_medical_C1_batchnorm2_running_mean is done with shape:  (128,)
# deep_medical_C1_batchnorm2_running_var is done with shape:  (128,)
# deep_medical_C1_conv3_weight is done with shape:  (192, 128, 7, 7, 1)
# deep_medical_C1_batchnorm3_gamma is done with shape:  (192,)
# deep_medical_C1_batchnorm3_beta is done with shape:  (192,)
# deep_medical_C1_batchnorm3_running_mean is done with shape:  (192,)
# deep_medical_C1_batchnorm3_running_var is done with shape:  (192,)
# deep_medical_C1_conv4_weight is done with shape:  (128, 768, 1, 1, 1)
# deep_medical_C1_batchnorm4_gamma is done with shape:  (128,)
# deep_medical_C1_batchnorm4_beta is done with shape:  (128,)
# deep_medical_C1_batchnorm4_running_mean is done with shape:  (128,)
# deep_medical_C1_batchnorm4_running_var is done with shape:  (128,)
# deep_medical_C1_conv5_weight is done with shape:  (128, 128, 7, 7, 1)
# deep_medical_C1_batchnorm5_gamma is done with shape:  (128,)
# deep_medical_C1_batchnorm5_beta is done with shape:  (128,)
# deep_medical_C1_batchnorm5_running_mean is done with shape:  (128,)
# deep_medical_C1_batchnorm5_running_var is done with shape:  (128,)
# deep_medical_C1_conv6_weight is done with shape:  (128, 128, 7, 1, 7)
# deep_medical_C1_batchnorm6_gamma is done with shape:  (128,)
# deep_medical_C1_batchnorm6_beta is done with shape:  (128,)
# deep_medical_C1_batchnorm6_running_mean is done with shape:  (128,)
# deep_medical_C1_batchnorm6_running_var is done with shape:  (128,)
# deep_medical_C1_conv7_weight is done with shape:  (128, 128, 7, 7, 1)
# deep_medical_C1_batchnorm7_gamma is done with shape:  (128,)
# deep_medical_C1_batchnorm7_beta is done with shape:  (128,)
# deep_medical_C1_batchnorm7_running_mean is done with shape:  (128,)
# deep_medical_C1_batchnorm7_running_var is done with shape:  (128,)
# deep_medical_C1_conv8_weight is done with shape:  (192, 128, 7, 1, 7)
# deep_medical_C1_batchnorm8_gamma is done with shape:  (192,)
# deep_medical_C1_batchnorm8_beta is done with shape:  (192,)
# deep_medical_C1_batchnorm8_running_mean is done with shape:  (192,)
# deep_medical_C1_batchnorm8_running_var is done with shape:  (192,)
# deep_medical_C1_conv9_weight is done with shape:  (192, 768, 1, 1, 1)
# deep_medical_C1_batchnorm9_gamma is done with shape:  (192,)
# deep_medical_C1_batchnorm9_beta is done with shape:  (192,)
# deep_medical_C1_batchnorm9_running_mean is done with shape:  (192,)
# deep_medical_C1_batchnorm9_running_var is done with shape:  (192,)
# deep_medical_C2_conv0_weight is done with shape:  (192, 768, 1, 1, 1)
# deep_medical_C2_batchnorm0_gamma is done with shape:  (192,)
# deep_medical_C2_batchnorm0_beta is done with shape:  (192,)
# deep_medical_C2_batchnorm0_running_mean is done with shape:  (192,)
# deep_medical_C2_batchnorm0_running_var is done with shape:  (192,)
# deep_medical_C2_conv1_weight is done with shape:  (160, 768, 1, 1, 1)
# deep_medical_C2_batchnorm1_gamma is done with shape:  (160,)
# deep_medical_C2_batchnorm1_beta is done with shape:  (160,)
# deep_medical_C2_batchnorm1_running_mean is done with shape:  (160,)
# deep_medical_C2_batchnorm1_running_var is done with shape:  (160,)
# deep_medical_C2_conv2_weight is done with shape:  (160, 160, 7, 1, 7)
# deep_medical_C2_batchnorm2_gamma is done with shape:  (160,)
# deep_medical_C2_batchnorm2_beta is done with shape:  (160,)
# deep_medical_C2_batchnorm2_running_mean is done with shape:  (160,)
# deep_medical_C2_batchnorm2_running_var is done with shape:  (160,)
# deep_medical_C2_conv3_weight is done with shape:  (192, 160, 7, 7, 1)
# deep_medical_C2_batchnorm3_gamma is done with shape:  (192,)
# deep_medical_C2_batchnorm3_beta is done with shape:  (192,)
# deep_medical_C2_batchnorm3_running_mean is done with shape:  (192,)
# deep_medical_C2_batchnorm3_running_var is done with shape:  (192,)
# deep_medical_C2_conv4_weight is done with shape:  (160, 768, 1, 1, 1)
# deep_medical_C2_batchnorm4_gamma is done with shape:  (160,)
# deep_medical_C2_batchnorm4_beta is done with shape:  (160,)
# deep_medical_C2_batchnorm4_running_mean is done with shape:  (160,)
# deep_medical_C2_batchnorm4_running_var is done with shape:  (160,)
# deep_medical_C2_conv5_weight is done with shape:  (160, 160, 7, 7, 1)
# deep_medical_C2_batchnorm5_gamma is done with shape:  (160,)
# deep_medical_C2_batchnorm5_beta is done with shape:  (160,)
# deep_medical_C2_batchnorm5_running_mean is done with shape:  (160,)
# deep_medical_C2_batchnorm5_running_var is done with shape:  (160,)
# deep_medical_C2_conv6_weight is done with shape:  (160, 160, 7, 1, 7)
# deep_medical_C2_batchnorm6_gamma is done with shape:  (160,)
# deep_medical_C2_batchnorm6_beta is done with shape:  (160,)
# deep_medical_C2_batchnorm6_running_mean is done with shape:  (160,)
# deep_medical_C2_batchnorm6_running_var is done with shape:  (160,)
# deep_medical_C2_conv7_weight is done with shape:  (160, 160, 7, 7, 1)
# deep_medical_C2_batchnorm7_gamma is done with shape:  (160,)
# deep_medical_C2_batchnorm7_beta is done with shape:  (160,)
# deep_medical_C2_batchnorm7_running_mean is done with shape:  (160,)
# deep_medical_C2_batchnorm7_running_var is done with shape:  (160,)
# deep_medical_C2_conv8_weight is done with shape:  (192, 160, 7, 1, 7)
# deep_medical_C2_batchnorm8_gamma is done with shape:  (192,)
# deep_medical_C2_batchnorm8_beta is done with shape:  (192,)
# deep_medical_C2_batchnorm8_running_mean is done with shape:  (192,)
# deep_medical_C2_batchnorm8_running_var is done with shape:  (192,)
# deep_medical_C2_conv9_weight is done with shape:  (192, 768, 1, 1, 1)
# deep_medical_C2_batchnorm9_gamma is done with shape:  (192,)
# deep_medical_C2_batchnorm9_beta is done with shape:  (192,)
# deep_medical_C2_batchnorm9_running_mean is done with shape:  (192,)
# deep_medical_C2_batchnorm9_running_var is done with shape:  (192,)
# deep_medical_C3_conv0_weight is done with shape:  (192, 768, 1, 1, 1)
# deep_medical_C3_batchnorm0_gamma is done with shape:  (192,)
# deep_medical_C3_batchnorm0_beta is done with shape:  (192,)
# deep_medical_C3_batchnorm0_running_mean is done with shape:  (192,)
# deep_medical_C3_batchnorm0_running_var is done with shape:  (192,)
# deep_medical_C3_conv1_weight is done with shape:  (160, 768, 1, 1, 1)
# deep_medical_C3_batchnorm1_gamma is done with shape:  (160,)
# deep_medical_C3_batchnorm1_beta is done with shape:  (160,)
# deep_medical_C3_batchnorm1_running_mean is done with shape:  (160,)
# deep_medical_C3_batchnorm1_running_var is done with shape:  (160,)
# deep_medical_C3_conv2_weight is done with shape:  (160, 160, 7, 1, 7)
# deep_medical_C3_batchnorm2_gamma is done with shape:  (160,)
# deep_medical_C3_batchnorm2_beta is done with shape:  (160,)
# deep_medical_C3_batchnorm2_running_mean is done with shape:  (160,)
# deep_medical_C3_batchnorm2_running_var is done with shape:  (160,)
# deep_medical_C3_conv3_weight is done with shape:  (192, 160, 7, 7, 1)
# deep_medical_C3_batchnorm3_gamma is done with shape:  (192,)
# deep_medical_C3_batchnorm3_beta is done with shape:  (192,)
# deep_medical_C3_batchnorm3_running_mean is done with shape:  (192,)
# deep_medical_C3_batchnorm3_running_var is done with shape:  (192,)
# deep_medical_C3_conv4_weight is done with shape:  (160, 768, 1, 1, 1)
# deep_medical_C3_batchnorm4_gamma is done with shape:  (160,)
# deep_medical_C3_batchnorm4_beta is done with shape:  (160,)
# deep_medical_C3_batchnorm4_running_mean is done with shape:  (160,)
# deep_medical_C3_batchnorm4_running_var is done with shape:  (160,)
# deep_medical_C3_conv5_weight is done with shape:  (160, 160, 7, 7, 1)
# deep_medical_C3_batchnorm5_gamma is done with shape:  (160,)
# deep_medical_C3_batchnorm5_beta is done with shape:  (160,)
# deep_medical_C3_batchnorm5_running_mean is done with shape:  (160,)
# deep_medical_C3_batchnorm5_running_var is done with shape:  (160,)
# deep_medical_C3_conv6_weight is done with shape:  (160, 160, 7, 1, 7)
# deep_medical_C3_batchnorm6_gamma is done with shape:  (160,)
# deep_medical_C3_batchnorm6_beta is done with shape:  (160,)
# deep_medical_C3_batchnorm6_running_mean is done with shape:  (160,)
# deep_medical_C3_batchnorm6_running_var is done with shape:  (160,)
# deep_medical_C3_conv7_weight is done with shape:  (160, 160, 7, 7, 1)
# deep_medical_C3_batchnorm7_gamma is done with shape:  (160,)
# deep_medical_C3_batchnorm7_beta is done with shape:  (160,)
# deep_medical_C3_batchnorm7_running_mean is done with shape:  (160,)
# deep_medical_C3_batchnorm7_running_var is done with shape:  (160,)
# deep_medical_C3_conv8_weight is done with shape:  (192, 160, 7, 1, 7)
# deep_medical_C3_batchnorm8_gamma is done with shape:  (192,)
# deep_medical_C3_batchnorm8_beta is done with shape:  (192,)
# deep_medical_C3_batchnorm8_running_mean is done with shape:  (192,)
# deep_medical_C3_batchnorm8_running_var is done with shape:  (192,)
# deep_medical_C3_conv9_weight is done with shape:  (192, 768, 1, 1, 1)
# deep_medical_C3_batchnorm9_gamma is done with shape:  (192,)
# deep_medical_C3_batchnorm9_beta is done with shape:  (192,)
# deep_medical_C3_batchnorm9_running_mean is done with shape:  (192,)
# deep_medical_C3_batchnorm9_running_var is done with shape:  (192,)
# deep_medical_C4_conv0_weight is done with shape:  (192, 768, 1, 1, 1)
# deep_medical_C4_batchnorm0_gamma is done with shape:  (192,)
# deep_medical_C4_batchnorm0_beta is done with shape:  (192,)
# deep_medical_C4_batchnorm0_running_mean is done with shape:  (192,)
# deep_medical_C4_batchnorm0_running_var is done with shape:  (192,)
# deep_medical_C4_conv1_weight is done with shape:  (192, 768, 1, 1, 1)
# deep_medical_C4_batchnorm1_gamma is done with shape:  (192,)
# deep_medical_C4_batchnorm1_beta is done with shape:  (192,)
# deep_medical_C4_batchnorm1_running_mean is done with shape:  (192,)
# deep_medical_C4_batchnorm1_running_var is done with shape:  (192,)
# deep_medical_C4_conv2_weight is done with shape:  (192, 192, 7, 1, 7)
# deep_medical_C4_batchnorm2_gamma is done with shape:  (192,)
# deep_medical_C4_batchnorm2_beta is done with shape:  (192,)
# deep_medical_C4_batchnorm2_running_mean is done with shape:  (192,)
# deep_medical_C4_batchnorm2_running_var is done with shape:  (192,)
# deep_medical_C4_conv3_weight is done with shape:  (192, 192, 7, 7, 1)
# deep_medical_C4_batchnorm3_gamma is done with shape:  (192,)
# deep_medical_C4_batchnorm3_beta is done with shape:  (192,)
# deep_medical_C4_batchnorm3_running_mean is done with shape:  (192,)
# deep_medical_C4_batchnorm3_running_var is done with shape:  (192,)
# deep_medical_C4_conv4_weight is done with shape:  (192, 768, 1, 1, 1)
# deep_medical_C4_batchnorm4_gamma is done with shape:  (192,)
# deep_medical_C4_batchnorm4_beta is done with shape:  (192,)
# deep_medical_C4_batchnorm4_running_mean is done with shape:  (192,)
# deep_medical_C4_batchnorm4_running_var is done with shape:  (192,)
# deep_medical_C4_conv5_weight is done with shape:  (192, 192, 7, 7, 1)
# deep_medical_C4_batchnorm5_gamma is done with shape:  (192,)
# deep_medical_C4_batchnorm5_beta is done with shape:  (192,)
# deep_medical_C4_batchnorm5_running_mean is done with shape:  (192,)
# deep_medical_C4_batchnorm5_running_var is done with shape:  (192,)
# deep_medical_C4_conv6_weight is done with shape:  (192, 192, 7, 1, 7)
# deep_medical_C4_batchnorm6_gamma is done with shape:  (192,)
# deep_medical_C4_batchnorm6_beta is done with shape:  (192,)
# deep_medical_C4_batchnorm6_running_mean is done with shape:  (192,)
# deep_medical_C4_batchnorm6_running_var is done with shape:  (192,)
# deep_medical_C4_conv7_weight is done with shape:  (192, 192, 7, 7, 1)
# deep_medical_C4_batchnorm7_gamma is done with shape:  (192,)
# deep_medical_C4_batchnorm7_beta is done with shape:  (192,)
# deep_medical_C4_batchnorm7_running_mean is done with shape:  (192,)
# deep_medical_C4_batchnorm7_running_var is done with shape:  (192,)
# deep_medical_C4_conv8_weight is done with shape:  (192, 192, 7, 1, 7)
# deep_medical_C4_batchnorm8_gamma is done with shape:  (192,)
# deep_medical_C4_batchnorm8_beta is done with shape:  (192,)
# deep_medical_C4_batchnorm8_running_mean is done with shape:  (192,)
# deep_medical_C4_batchnorm8_running_var is done with shape:  (192,)
# deep_medical_C4_conv9_weight is done with shape:  (192, 768, 1, 1, 1)
# deep_medical_C4_batchnorm9_gamma is done with shape:  (192,)
# deep_medical_C4_batchnorm9_beta is done with shape:  (192,)
# deep_medical_C4_batchnorm9_running_mean is done with shape:  (192,)
# deep_medical_C4_batchnorm9_running_var is done with shape:  (192,)
# deep_medical_D_conv0_weight is done with shape:  (192, 768, 1, 1, 1)
# deep_medical_D_batchnorm0_gamma is done with shape:  (192,)
# deep_medical_D_batchnorm0_beta is done with shape:  (192,)
# deep_medical_D_batchnorm0_running_mean is done with shape:  (192,)
# deep_medical_D_batchnorm0_running_var is done with shape:  (192,)
# deep_medical_D_conv1_weight is done with shape:  (320, 192, 3, 3, 3)
# deep_medical_D_batchnorm1_gamma is done with shape:  (320,)
# deep_medical_D_batchnorm1_beta is done with shape:  (320,)
# deep_medical_D_batchnorm1_running_mean is done with shape:  (320,)
# deep_medical_D_batchnorm1_running_var is done with shape:  (320,)
# deep_medical_D_conv2_weight is done with shape:  (192, 768, 1, 1, 1)
# deep_medical_D_batchnorm2_gamma is done with shape:  (192,)
# deep_medical_D_batchnorm2_beta is done with shape:  (192,)
# deep_medical_D_batchnorm2_running_mean is done with shape:  (192,)
# deep_medical_D_batchnorm2_running_var is done with shape:  (192,)
# deep_medical_D_conv3_weight is done with shape:  (192, 192, 7, 1, 7)
# deep_medical_D_batchnorm3_gamma is done with shape:  (192,)
# deep_medical_D_batchnorm3_beta is done with shape:  (192,)
# deep_medical_D_batchnorm3_running_mean is done with shape:  (192,)
# deep_medical_D_batchnorm3_running_var is done with shape:  (192,)
# deep_medical_D_conv4_weight is done with shape:  (192, 192, 7, 7, 1)
# deep_medical_D_batchnorm4_gamma is done with shape:  (192,)
# deep_medical_D_batchnorm4_beta is done with shape:  (192,)
# deep_medical_D_batchnorm4_running_mean is done with shape:  (192,)
# deep_medical_D_batchnorm4_running_var is done with shape:  (192,)
# deep_medical_D_conv5_weight is done with shape:  (192, 192, 3, 3, 3)
# deep_medical_D_batchnorm5_gamma is done with shape:  (192,)
# deep_medical_D_batchnorm5_beta is done with shape:  (192,)
# deep_medical_D_batchnorm5_running_mean is done with shape:  (192,)
# deep_medical_D_batchnorm5_running_var is done with shape:  (192,)
# deep_medical_E1_conv0_weight is done with shape:  (320, 1280, 1, 1, 1)
# deep_medical_E1_batchnorm0_gamma is done with shape:  (320,)
# deep_medical_E1_batchnorm0_beta is done with shape:  (320,)
# deep_medical_E1_batchnorm0_running_mean is done with shape:  (320,)
# deep_medical_E1_batchnorm0_running_var is done with shape:  (320,)
# deep_medical_E1_conv1_weight is done with shape:  (384, 1280, 1, 1, 1)
# deep_medical_E1_batchnorm1_gamma is done with shape:  (384,)
# deep_medical_E1_batchnorm1_beta is done with shape:  (384,)
# deep_medical_E1_batchnorm1_running_mean is done with shape:  (384,)
# deep_medical_E1_batchnorm1_running_var is done with shape:  (384,)
# deep_medical_E1_conv2_weight is done with shape:  (384, 384, 3, 1, 3)
# deep_medical_E1_batchnorm2_gamma is done with shape:  (384,)
# deep_medical_E1_batchnorm2_beta is done with shape:  (384,)
# deep_medical_E1_batchnorm2_running_mean is done with shape:  (384,)
# deep_medical_E1_batchnorm2_running_var is done with shape:  (384,)
# deep_medical_E1_conv3_weight is done with shape:  (384, 384, 3, 3, 1)
# deep_medical_E1_batchnorm3_gamma is done with shape:  (384,)
# deep_medical_E1_batchnorm3_beta is done with shape:  (384,)
# deep_medical_E1_batchnorm3_running_mean is done with shape:  (384,)
# deep_medical_E1_batchnorm3_running_var is done with shape:  (384,)
# deep_medical_E1_conv4_weight is done with shape:  (448, 1280, 1, 1, 1)
# deep_medical_E1_batchnorm4_gamma is done with shape:  (448,)
# deep_medical_E1_batchnorm4_beta is done with shape:  (448,)
# deep_medical_E1_batchnorm4_running_mean is done with shape:  (448,)
# deep_medical_E1_batchnorm4_running_var is done with shape:  (448,)
# deep_medical_E1_conv5_weight is done with shape:  (384, 448, 3, 3, 3)
# deep_medical_E1_batchnorm5_gamma is done with shape:  (384,)
# deep_medical_E1_batchnorm5_beta is done with shape:  (384,)
# deep_medical_E1_batchnorm5_running_mean is done with shape:  (384,)
# deep_medical_E1_batchnorm5_running_var is done with shape:  (384,)
# deep_medical_E1_conv6_weight is done with shape:  (384, 384, 3, 1, 3)
# deep_medical_E1_batchnorm6_gamma is done with shape:  (384,)
# deep_medical_E1_batchnorm6_beta is done with shape:  (384,)
# deep_medical_E1_batchnorm6_running_mean is done with shape:  (384,)
# deep_medical_E1_batchnorm6_running_var is done with shape:  (384,)
# deep_medical_E1_conv7_weight is done with shape:  (384, 384, 3, 3, 1)
# deep_medical_E1_batchnorm7_gamma is done with shape:  (384,)
# deep_medical_E1_batchnorm7_beta is done with shape:  (384,)
# deep_medical_E1_batchnorm7_running_mean is done with shape:  (384,)
# deep_medical_E1_batchnorm7_running_var is done with shape:  (384,)
# deep_medical_E1_conv8_weight is done with shape:  (192, 1280, 1, 1, 1)
# deep_medical_E1_batchnorm8_gamma is done with shape:  (192,)
# deep_medical_E1_batchnorm8_beta is done with shape:  (192,)
# deep_medical_E1_batchnorm8_running_mean is done with shape:  (192,)
# deep_medical_E1_batchnorm8_running_var is done with shape:  (192,)
# deep_medical_E2_conv0_weight is done with shape:  (320, 2048, 1, 1, 1)
# deep_medical_E2_batchnorm0_gamma is done with shape:  (320,)
# deep_medical_E2_batchnorm0_beta is done with shape:  (320,)
# deep_medical_E2_batchnorm0_running_mean is done with shape:  (320,)
# deep_medical_E2_batchnorm0_running_var is done with shape:  (320,)
# deep_medical_E2_conv1_weight is done with shape:  (384, 2048, 1, 1, 1)
# deep_medical_E2_batchnorm1_gamma is done with shape:  (384,)
# deep_medical_E2_batchnorm1_beta is done with shape:  (384,)
# deep_medical_E2_batchnorm1_running_mean is done with shape:  (384,)
# deep_medical_E2_batchnorm1_running_var is done with shape:  (384,)
# deep_medical_E2_conv2_weight is done with shape:  (384, 384, 3, 1, 3)
# deep_medical_E2_batchnorm2_gamma is done with shape:  (384,)
# deep_medical_E2_batchnorm2_beta is done with shape:  (384,)
# deep_medical_E2_batchnorm2_running_mean is done with shape:  (384,)
# deep_medical_E2_batchnorm2_running_var is done with shape:  (384,)
# deep_medical_E2_conv3_weight is done with shape:  (384, 384, 3, 3, 1)
# deep_medical_E2_batchnorm3_gamma is done with shape:  (384,)
# deep_medical_E2_batchnorm3_beta is done with shape:  (384,)
# deep_medical_E2_batchnorm3_running_mean is done with shape:  (384,)
# deep_medical_E2_batchnorm3_running_var is done with shape:  (384,)
# deep_medical_E2_conv4_weight is done with shape:  (448, 2048, 1, 1, 1)
# deep_medical_E2_batchnorm4_gamma is done with shape:  (448,)
# deep_medical_E2_batchnorm4_beta is done with shape:  (448,)
# deep_medical_E2_batchnorm4_running_mean is done with shape:  (448,)
# deep_medical_E2_batchnorm4_running_var is done with shape:  (448,)
# deep_medical_E2_conv5_weight is done with shape:  (384, 448, 3, 3, 3)
# deep_medical_E2_batchnorm5_gamma is done with shape:  (384,)
# deep_medical_E2_batchnorm5_beta is done with shape:  (384,)
# deep_medical_E2_batchnorm5_running_mean is done with shape:  (384,)
# deep_medical_E2_batchnorm5_running_var is done with shape:  (384,)
# deep_medical_E2_conv6_weight is done with shape:  (384, 384, 3, 1, 3)
# deep_medical_E2_batchnorm6_gamma is done with shape:  (384,)
# deep_medical_E2_batchnorm6_beta is done with shape:  (384,)
# deep_medical_E2_batchnorm6_running_mean is done with shape:  (384,)
# deep_medical_E2_batchnorm6_running_var is done with shape:  (384,)
# deep_medical_E2_conv7_weight is done with shape:  (384, 384, 3, 3, 1)
# deep_medical_E2_batchnorm7_gamma is done with shape:  (384,)
# deep_medical_E2_batchnorm7_beta is done with shape:  (384,)
# deep_medical_E2_batchnorm7_running_mean is done with shape:  (384,)
# deep_medical_E2_batchnorm7_running_var is done with shape:  (384,)
# deep_medical_E2_conv8_weight is done with shape:  (192, 2048, 1, 1, 1)
# deep_medical_E2_batchnorm8_gamma is done with shape:  (192,)
# deep_medical_E2_batchnorm8_beta is done with shape:  (192,)
# deep_medical_E2_batchnorm8_running_mean is done with shape:  (192,)
# deep_medical_E2_batchnorm8_running_var is done with shape:  (192,)
# deep_medical_dense0_weight is skipped with shape:  (2, 2048)
# deep_medical_dense0_bias is skipped with shape:  (2,)
# <bound method Block.summary of I3D_InceptionV3(
#   (features): HybridSequential(
#     (0): HybridSequential(
#       (0): Conv3D(3 -> 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 0, 0), bias=False)
#       (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=32)
#       (2): Activation(relu)
#     )
#     (1): HybridSequential(
#       (0): Conv3D(32 -> 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=32)
#       (2): Activation(relu)
#     )
#     (2): HybridSequential(
#       (0): Conv3D(32 -> 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#       (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#       (2): Activation(relu)
#     )
#     (3): MaxPool3D(size=(3, 3, 3), stride=(1, 2, 2), padding=(1, 0, 0), ceil_mode=False, global_pool=False, pool_type=max, layout=NCDHW)
#     (4): HybridSequential(
#       (0): Conv3D(64 -> 80, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=80)
#       (2): Activation(relu)
#     )
#     (5): HybridSequential(
#       (0): Conv3D(80 -> 192, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#       (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#       (2): Activation(relu)
#     )
#     (6): MaxPool3D(size=(3, 3, 3), stride=(1, 2, 2), padding=(1, 0, 0), ceil_mode=False, global_pool=False, pool_type=max, layout=NCDHW)
#     (7): HybridConcurrent(
#       (0): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(192 -> 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#           (2): Activation(relu)
#         )
#       )
#       (1): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(192 -> 48, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=48)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(48 -> 64, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#           (2): Activation(relu)
#         )
#       )
#       (2): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(192 -> 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(64 -> 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=96)
#           (2): Activation(relu)
#         )
#         (2): HybridSequential(
#           (0): Conv3D(96 -> 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=96)
#           (2): Activation(relu)
#         )
#       )
#       (3): HybridSequential(
#         (0): AvgPool3D(size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), ceil_mode=False, global_pool=False, pool_type=avg, layout=NCDHW)
#         (1): HybridSequential(
#           (0): Conv3D(192 -> 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=32)
#           (2): Activation(relu)
#         )
#       )
#     )
#     (8): HybridConcurrent(
#       (0): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(256 -> 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#           (2): Activation(relu)
#         )
#       )
#       (1): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(256 -> 48, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=48)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(48 -> 64, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#           (2): Activation(relu)
#         )
#       )
#       (2): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(256 -> 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(64 -> 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=96)
#           (2): Activation(relu)
#         )
#         (2): HybridSequential(
#           (0): Conv3D(96 -> 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=96)
#           (2): Activation(relu)
#         )
#       )
#       (3): HybridSequential(
#         (0): AvgPool3D(size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), ceil_mode=False, global_pool=False, pool_type=avg, layout=NCDHW)
#         (1): HybridSequential(
#           (0): Conv3D(256 -> 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#           (2): Activation(relu)
#         )
#       )
#     )
#     (9): HybridConcurrent(
#       (0): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(288 -> 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#           (2): Activation(relu)
#         )
#       )
#       (1): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(288 -> 48, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=48)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(48 -> 64, kernel_size=(5, 5, 5), stride=(1, 1, 1), padding=(2, 2, 2), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#           (2): Activation(relu)
#         )
#       )
#       (2): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(288 -> 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(64 -> 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=96)
#           (2): Activation(relu)
#         )
#         (2): HybridSequential(
#           (0): Conv3D(96 -> 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=96)
#           (2): Activation(relu)
#         )
#       )
#       (3): HybridSequential(
#         (0): AvgPool3D(size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), ceil_mode=False, global_pool=False, pool_type=avg, layout=NCDHW)
#         (1): HybridSequential(
#           (0): Conv3D(288 -> 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#           (2): Activation(relu)
#         )
#       )
#     )
#     (10): HybridConcurrent(
#       (0): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(288 -> 384, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 0, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=384)
#           (2): Activation(relu)
#         )
#       )
#       (1): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(288 -> 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=64)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(64 -> 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=96)
#           (2): Activation(relu)
#         )
#         (2): HybridSequential(
#           (0): Conv3D(96 -> 96, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 0, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=96)
#           (2): Activation(relu)
#         )
#       )
#       (2): HybridSequential(
#         (0): MaxPool3D(size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 0, 0), ceil_mode=False, global_pool=False, pool_type=max, layout=NCDHW)
#       )
#     )
#     (11): HybridConcurrent(
#       (0): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#       (1): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=128)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(128 -> 128, kernel_size=(7, 1, 7), stride=(1, 1, 1), padding=(3, 0, 3), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=128)
#           (2): Activation(relu)
#         )
#         (2): HybridSequential(
#           (0): Conv3D(128 -> 192, kernel_size=(7, 7, 1), stride=(1, 1, 1), padding=(3, 3, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#       (2): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=128)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(128 -> 128, kernel_size=(7, 7, 1), stride=(1, 1, 1), padding=(3, 3, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=128)
#           (2): Activation(relu)
#         )
#         (2): HybridSequential(
#           (0): Conv3D(128 -> 128, kernel_size=(7, 1, 7), stride=(1, 1, 1), padding=(3, 0, 3), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=128)
#           (2): Activation(relu)
#         )
#         (3): HybridSequential(
#           (0): Conv3D(128 -> 128, kernel_size=(7, 7, 1), stride=(1, 1, 1), padding=(3, 3, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=128)
#           (2): Activation(relu)
#         )
#         (4): HybridSequential(
#           (0): Conv3D(128 -> 192, kernel_size=(7, 1, 7), stride=(1, 1, 1), padding=(3, 0, 3), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#       (3): HybridSequential(
#         (0): AvgPool3D(size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), ceil_mode=False, global_pool=False, pool_type=avg, layout=NCDHW)
#         (1): HybridSequential(
#           (0): Conv3D(768 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#     )
#     (12): HybridConcurrent(
#       (0): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#       (1): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 160, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=160)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(160 -> 160, kernel_size=(7, 1, 7), stride=(1, 1, 1), padding=(3, 0, 3), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=160)
#           (2): Activation(relu)
#         )
#         (2): HybridSequential(
#           (0): Conv3D(160 -> 192, kernel_size=(7, 7, 1), stride=(1, 1, 1), padding=(3, 3, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#       (2): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 160, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=160)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(160 -> 160, kernel_size=(7, 7, 1), stride=(1, 1, 1), padding=(3, 3, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=160)
#           (2): Activation(relu)
#         )
#         (2): HybridSequential(
#           (0): Conv3D(160 -> 160, kernel_size=(7, 1, 7), stride=(1, 1, 1), padding=(3, 0, 3), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=160)
#           (2): Activation(relu)
#         )
#         (3): HybridSequential(
#           (0): Conv3D(160 -> 160, kernel_size=(7, 7, 1), stride=(1, 1, 1), padding=(3, 3, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=160)
#           (2): Activation(relu)
#         )
#         (4): HybridSequential(
#           (0): Conv3D(160 -> 192, kernel_size=(7, 1, 7), stride=(1, 1, 1), padding=(3, 0, 3), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#       (3): HybridSequential(
#         (0): AvgPool3D(size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), ceil_mode=False, global_pool=False, pool_type=avg, layout=NCDHW)
#         (1): HybridSequential(
#           (0): Conv3D(768 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#     )
#     (13): HybridConcurrent(
#       (0): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#       (1): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 160, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=160)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(160 -> 160, kernel_size=(7, 1, 7), stride=(1, 1, 1), padding=(3, 0, 3), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=160)
#           (2): Activation(relu)
#         )
#         (2): HybridSequential(
#           (0): Conv3D(160 -> 192, kernel_size=(7, 7, 1), stride=(1, 1, 1), padding=(3, 3, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#       (2): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 160, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=160)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(160 -> 160, kernel_size=(7, 7, 1), stride=(1, 1, 1), padding=(3, 3, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=160)
#           (2): Activation(relu)
#         )
#         (2): HybridSequential(
#           (0): Conv3D(160 -> 160, kernel_size=(7, 1, 7), stride=(1, 1, 1), padding=(3, 0, 3), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=160)
#           (2): Activation(relu)
#         )
#         (3): HybridSequential(
#           (0): Conv3D(160 -> 160, kernel_size=(7, 7, 1), stride=(1, 1, 1), padding=(3, 3, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=160)
#           (2): Activation(relu)
#         )
#         (4): HybridSequential(
#           (0): Conv3D(160 -> 192, kernel_size=(7, 1, 7), stride=(1, 1, 1), padding=(3, 0, 3), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#       (3): HybridSequential(
#         (0): AvgPool3D(size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), ceil_mode=False, global_pool=False, pool_type=avg, layout=NCDHW)
#         (1): HybridSequential(
#           (0): Conv3D(768 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#     )
#     (14): HybridConcurrent(
#       (0): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#       (1): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(192 -> 192, kernel_size=(7, 1, 7), stride=(1, 1, 1), padding=(3, 0, 3), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#         (2): HybridSequential(
#           (0): Conv3D(192 -> 192, kernel_size=(7, 7, 1), stride=(1, 1, 1), padding=(3, 3, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#       (2): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(192 -> 192, kernel_size=(7, 7, 1), stride=(1, 1, 1), padding=(3, 3, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#         (2): HybridSequential(
#           (0): Conv3D(192 -> 192, kernel_size=(7, 1, 7), stride=(1, 1, 1), padding=(3, 0, 3), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#         (3): HybridSequential(
#           (0): Conv3D(192 -> 192, kernel_size=(7, 7, 1), stride=(1, 1, 1), padding=(3, 3, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#         (4): HybridSequential(
#           (0): Conv3D(192 -> 192, kernel_size=(7, 1, 7), stride=(1, 1, 1), padding=(3, 0, 3), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#       (3): HybridSequential(
#         (0): AvgPool3D(size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), ceil_mode=False, global_pool=False, pool_type=avg, layout=NCDHW)
#         (1): HybridSequential(
#           (0): Conv3D(768 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#     )
#     (15): HybridConcurrent(
#       (0): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(192 -> 320, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 0, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=320)
#           (2): Activation(relu)
#         )
#       )
#       (1): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(768 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#         (1): HybridSequential(
#           (0): Conv3D(192 -> 192, kernel_size=(7, 1, 7), stride=(1, 1, 1), padding=(3, 0, 3), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#         (2): HybridSequential(
#           (0): Conv3D(192 -> 192, kernel_size=(7, 7, 1), stride=(1, 1, 1), padding=(3, 3, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#         (3): HybridSequential(
#           (0): Conv3D(192 -> 192, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 0, 0), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#       (2): HybridSequential(
#         (0): MaxPool3D(size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 0, 0), ceil_mode=False, global_pool=False, pool_type=max, layout=NCDHW)
#       )
#     )
#     (16): HybridConcurrent(
#       (0): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(1280 -> 320, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=320)
#           (2): Activation(relu)
#         )
#       )
#       (1): HybridSequential(
#         (0): HybridSequential(
#           (0): HybridSequential(
#             (0): Conv3D(1280 -> 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=384)
#             (2): Activation(relu)
#           )
#         )
#         (1): HybridConcurrent(
#           (0): HybridSequential(
#             (0): HybridSequential(
#               (0): Conv3D(384 -> 384, kernel_size=(3, 1, 3), stride=(1, 1, 1), padding=(1, 0, 1), bias=False)
#               (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=384)
#               (2): Activation(relu)
#             )
#           )
#           (1): HybridSequential(
#             (0): HybridSequential(
#               (0): Conv3D(384 -> 384, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0), bias=False)
#               (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=384)
#               (2): Activation(relu)
#             )
#           )
#         )
#       )
#       (2): HybridSequential(
#         (0): HybridSequential(
#           (0): HybridSequential(
#             (0): Conv3D(1280 -> 448, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=448)
#             (2): Activation(relu)
#           )
#           (1): HybridSequential(
#             (0): Conv3D(448 -> 384, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#             (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=384)
#             (2): Activation(relu)
#           )
#         )
#         (1): HybridConcurrent(
#           (0): HybridSequential(
#             (0): HybridSequential(
#               (0): Conv3D(384 -> 384, kernel_size=(3, 1, 3), stride=(1, 1, 1), padding=(1, 0, 1), bias=False)
#               (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=384)
#               (2): Activation(relu)
#             )
#           )
#           (1): HybridSequential(
#             (0): HybridSequential(
#               (0): Conv3D(384 -> 384, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0), bias=False)
#               (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=384)
#               (2): Activation(relu)
#             )
#           )
#         )
#       )
#       (3): HybridSequential(
#         (0): AvgPool3D(size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), ceil_mode=False, global_pool=False, pool_type=avg, layout=NCDHW)
#         (1): HybridSequential(
#           (0): Conv3D(1280 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#     )
#     (17): HybridConcurrent(
#       (0): HybridSequential(
#         (0): HybridSequential(
#           (0): Conv3D(2048 -> 320, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=320)
#           (2): Activation(relu)
#         )
#       )
#       (1): HybridSequential(
#         (0): HybridSequential(
#           (0): HybridSequential(
#             (0): Conv3D(2048 -> 384, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=384)
#             (2): Activation(relu)
#           )
#         )
#         (1): HybridConcurrent(
#           (0): HybridSequential(
#             (0): HybridSequential(
#               (0): Conv3D(384 -> 384, kernel_size=(3, 1, 3), stride=(1, 1, 1), padding=(1, 0, 1), bias=False)
#               (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=384)
#               (2): Activation(relu)
#             )
#           )
#           (1): HybridSequential(
#             (0): HybridSequential(
#               (0): Conv3D(384 -> 384, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0), bias=False)
#               (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=384)
#               (2): Activation(relu)
#             )
#           )
#         )
#       )
#       (2): HybridSequential(
#         (0): HybridSequential(
#           (0): HybridSequential(
#             (0): Conv3D(2048 -> 448, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=448)
#             (2): Activation(relu)
#           )
#           (1): HybridSequential(
#             (0): Conv3D(448 -> 384, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#             (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=384)
#             (2): Activation(relu)
#           )
#         )
#         (1): HybridConcurrent(
#           (0): HybridSequential(
#             (0): HybridSequential(
#               (0): Conv3D(384 -> 384, kernel_size=(3, 1, 3), stride=(1, 1, 1), padding=(1, 0, 1), bias=False)
#               (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=384)
#               (2): Activation(relu)
#             )
#           )
#           (1): HybridSequential(
#             (0): HybridSequential(
#               (0): Conv3D(384 -> 384, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0), bias=False)
#               (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=384)
#               (2): Activation(relu)
#             )
#           )
#         )
#       )
#       (3): HybridSequential(
#         (0): AvgPool3D(size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), ceil_mode=False, global_pool=False, pool_type=avg, layout=NCDHW)
#         (1): HybridSequential(
#           (0): Conv3D(2048 -> 192, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (1): BatchNorm(axis=1, eps=0.001, momentum=0.9, fix_gamma=False, use_global_stats=False, in_channels=192)
#           (2): Activation(relu)
#         )
#       )
#     )
#     (18): GlobalAvgPool3D(size=(1, 1, 1), stride=(1, 1, 1), padding=(0, 0, 0), ceil_mode=True, global_pool=True, pool_type=avg, layout=NCDHW)
#   )
#   (head): HybridSequential(
#     (0): Dropout(p = 0.5, axes=())
#     (1): Dense(2048 -> 2, linear)
#   )
#   (output): Dense(2048 -> 2, linear)
# )>

# %%
# TENSORFLOW
model_top = Sequential()
model_top.add(GlobalAveragePooling2D(input_shape=base_model.output_shape[1:], data_format=None)),  
model_top.add(Dense(256, activation='relu'))
model_top.add(Dropout(0.5))
model_top.add(Dense(1, activation='sigmoid')) 

model = Model(inputs=base_model.input, outputs=model_top(base_model.output))

model.compile(optimizer=Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08,decay=0.0), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Train

# %%
# TENSORFLOW
history = model.fit(
            train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            validation_data=validation_generator,
            validation_steps=nb_validation_samples // batch_size)

# %%
# MXNET
from mxnet import autograd

# Saved in the d2l package for later use
def training_procedure(handwritten_net, train_iter):
    global EPOCHS
    global ctx
    handwritten_net.initialize(mx.init.Xavier(), ctx=ctx, force_reinit=True)
    #handwritten_net(init = mx.init.Xavier(), ctx=ctx)
    optim = mx.optimizer.Adam(learning_rate=0.001, beta1=0.9, beta2=0.999, epsilon=1e-08, lazy_update=True)
    trainer = gluon.Trainer(handwritten_net.collect_params(), optim)
    # Use Accuracy as the evaluation metric.
    metric = mx.metric.Accuracy()
    softmax_cross_entropy_loss = gluon.loss.SoftmaxCrossEntropyLoss()
    
    
    for i in range(EPOCHS):
        # Loop over the train data iterator.
        for i, (features, labels) in enumerate(train_iter):
        #for batch in train_data:
            # Splits train data into multiple slices along batch_axis
            # and copy each slice into a context.
            ###data = gluon.utils.split_and_load(batch.data[0], ctx_list=ctx, batch_axis=0)
            # Splits train labels into multiple slices along batch_axis
            # and copy each slice into a context.
            ###label = gluon.utils.split_and_load(batch.label[0], ctx_list=ctx, batch_axis=0)
            outputs = []
            # Inside training scope
            with autograd.record():
                for x, y in zip(features, labels):
                    print(x.shape)
                    #help(handwritten_net)
                    z = handwritten_net(x)
                    # Computes softmax cross entropy loss.
                    loss = softmax_cross_entropy_loss(z, y)
                    # Backpropogate the error for one iteration.
                    loss.backward()
                    outputs.append(z)
            # Updates internal evaluation
            metric.update(labels, outputs)
            # Make one step of parameter update. Trainer needs to know the
            # batch size of data to normalize the gradient by 1/batch_size.
            trainer.step(features.shape[0])
        # Gets the evaluation result.
        name, acc = metric.get()
        # Reset evaluation result to initial state.
        metric.reset()
        print('training acc at epoch %d: %s=%f'%(i, name, acc))
    return handwritten_net

trained_model_mx = training_procedure(deep_medical_net, train_data_mx)
# Out:
# (3, 224, 224)
# ---------------------------------------------------------------------------
# MXNetError                                Traceback (most recent call last)
# <ipython-input-14-c3005c414eca> in <module>
#      49     return handwritten_net
#      50
# ---> 51 trained_model_mx = training_procedure(deep_medical_net, train_data_mx)
#
# <ipython-input-14-c3005c414eca> in training_procedure(handwritten_net, train_iter)
#      31                     print(x.shape)
#      32                     #help(handwritten_net)
# ---> 33                     z = handwritten_net(x)
#      34                     # Computes softmax cross entropy loss.
#      35                     loss = softmax_cross_entropy_loss(z, y)
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     546             hook(self, args)
#     547
# --> 548         out = self.forward(*args)
#     549
#     550         for hook in self._forward_hooks.values():
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     923                     params = {i: j.data(ctx) for i, j in self._reg_params.items()}
#     924
# --> 925                 return self.hybrid_forward(ndarray, x, *args, **params)
#     926
#     927         assert isinstance(x, Symbol), \
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/gluoncv/model_zoo/action_recognition/i3d_inceptionv3.py in hybrid_forward(self, F, x)
#     252
#     253     def hybrid_forward(self, F, x):
# --> 254         x = self.features(x)
#     255         x = F.squeeze(x, axis=(2, 3, 4))
#     256
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     546             hook(self, args)
#     547
# --> 548         out = self.forward(*args)
#     549
#     550         for hook in self._forward_hooks.values():
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     923                     params = {i: j.data(ctx) for i, j in self._reg_params.items()}
#     924
# --> 925                 return self.hybrid_forward(ndarray, x, *args, **params)
#     926
#     927         assert isinstance(x, Symbol), \
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/gluon/nn/basic_layers.py in hybrid_forward(self, F, x)
#     115     def hybrid_forward(self, F, x):
#     116         for block in self._children.values():
# --> 117             x = block(x)
#     118         return x
#     119
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     546             hook(self, args)
#     547
# --> 548         out = self.forward(*args)
#     549
#     550         for hook in self._forward_hooks.values():
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     923                     params = {i: j.data(ctx) for i, j in self._reg_params.items()}
#     924
# --> 925                 return self.hybrid_forward(ndarray, x, *args, **params)
#     926
#     927         assert isinstance(x, Symbol), \
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/gluon/nn/basic_layers.py in hybrid_forward(self, F, x)
#     115     def hybrid_forward(self, F, x):
#     116         for block in self._children.values():
# --> 117             x = block(x)
#     118         return x
#     119
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     546             hook(self, args)
#     547
# --> 548         out = self.forward(*args)
#     549
#     550         for hook in self._forward_hooks.values():
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     923                     params = {i: j.data(ctx) for i, j in self._reg_params.items()}
#     924
# --> 925                 return self.hybrid_forward(ndarray, x, *args, **params)
#     926
#     927         assert isinstance(x, Symbol), \
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/gluon/nn/conv_layers.py in hybrid_forward(self, F, x, weight, bias)
#     131     def hybrid_forward(self, F, x, weight, bias=None):
#     132         if bias is None:
# --> 133             act = getattr(F, self._op_name)(x, weight, name='fwd', **self._kwargs)
#     134         else:
#     135             act = getattr(F, self._op_name)(x, weight, bias, name='fwd', **self._kwargs)
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/ndarray/register.py in Convolution(data, weight, bias, kernel, stride, dilate, pad, num_filter, num_group, workspace, no_bias, cudnn_tune, cudnn_off, layout, out, name, **kwargs)
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/_ctypes/ndarray.py in _imperative_invoke(handle, ndargs, keys, vals, out)
#      90         c_str_array(keys),
#      91         c_str_array([str(s) for s in vals]),
# ---> 92         ctypes.byref(out_stypes)))
#      93
#      94     if original_output is not None:
#
# ~/Library/Python/3.7/lib/python/site-packages/mxnet/base.py in check_call(ret)
#     251     """
#     252     if ret != 0:
# --> 253         raise MXNetError(py_str(_LIB.MXGetLastError()))
#     254
#     255
#
# MXNetError: [18:10:52] src/operator/nn/convolution.cc:211: Check failed: dshp.ndim() == 5U (3 vs. 5) : Input data should be 5D in batch-num_filter-depth-y-x
# Stack trace:
#   [bt] (0) 1   libmxnet.so                         0x00000001503ed929 mxnet::op::NDArrayOpProp::~NDArrayOpProp() + 4473
#   [bt] (1) 2   libmxnet.so                         0x000000015071afbf void mxnet::op::ConcatCSRImpl<mshadow::cpu>(nnvm::NodeAttrs const&, mxnet::OpContext const&, std::__1::vector<mxnet::NDArray, std::__1::allocator<mxnet::NDArray> > const&, std::__1::vector<mxnet::OpReqType, std::__1::allocator<mxnet::OpReqType> > const&, std::__1::vector<mxnet::NDArray, std::__1::allocator<mxnet::NDArray> > const&) + 141199
#   [bt] (2) 3   libmxnet.so                         0x000000015196af23 mxnet::imperative::SetShapeType(mxnet::Context const&, nnvm::NodeAttrs const&, std::__1::vector<mxnet::NDArray*, std::__1::allocator<mxnet::NDArray*> > const&, std::__1::vector<mxnet::NDArray*, std::__1::allocator<mxnet::NDArray*> > const&, mxnet::DispatchMode*) + 1603
#   [bt] (3) 4   libmxnet.so                         0x000000015196983c mxnet::Imperative::Invoke(mxnet::Context const&, nnvm::NodeAttrs const&, std::__1::vector<mxnet::NDArray*, std::__1::allocator<mxnet::NDArray*> > const&, std::__1::vector<mxnet::NDArray*, std::__1::allocator<mxnet::NDArray*> > const&) + 716
#   [bt] (4) 5   libmxnet.so                         0x00000001518af48e SetNDInputsOutputs(nnvm::Op const*, std::__1::vector<mxnet::NDArray*, std::__1::allocator<mxnet::NDArray*> >*, std::__1::vector<mxnet::NDArray*, std::__1::allocator<mxnet::NDArray*> >*, int, void* const*, int*, int, int, void***) + 1582
#   [bt] (5) 6   libmxnet.so                         0x00000001518b01d0 MXImperativeInvokeEx + 176
#   [bt] (6) 7   _ctypes.cpython-37m-darwin.so       0x0000000111dee0d7 ffi_call_unix64 + 79

# %% [markdown]
# ## Visualize Results

# %%
import matplotlib.pyplot as plt

print(history.history.keys())

plt.figure()
plt.plot(history.history['accuracy'], 'orange', label='Training accuracy')
plt.plot(history.history['val_accuracy'], 'blue', label='Validation accuracy')
plt.plot(history.history['loss'], 'red', label='Training loss')
plt.plot(history.history['val_loss'], 'green', label='Validation loss')
plt.legend()
plt.show()

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

img_path='Open_I_abd_vs_CXRs/TEST/chest2.png' #change to location of chest x-ray
img_path2='Open_I_abd_vs_CXRs/TEST/abd2.png'  #change to location of abd x-ray
img = image.load_img(img_path, target_size=(img_width, img_height))
img2 = image.load_img(img_path2, target_size=(img_width, img_height))
plt.imshow(img)
plt.show()

img = image.img_to_array(img)
x = np.expand_dims(img, axis=0) * 1./255
score = model.predict(x)
print('Predicted:', score, 'Chest X-ray' if score < 0.5 else 'Abd X-ray')

plt.imshow(img2)
plt.show()

img = image.img_to_array(img2)
x = np.expand_dims(img2, axis=0) * 1./255
score2 = model.predict(x)
print('Predicted:', score2, 'Chest X-ray' if score2 < 0.5 else 'Abd X-ray')
