# %%
import gzip
import numpy as np
import pandas as pd
from time import time

from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import TensorBoard
# LOW LEVEL
from tensorflow.keras.layers import Flatten

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard

# %%
import time

start = time.process_time()
# your function here
end = time.process_time()
print("This is the general error magnitude: ", end - start)
# Out:
# This is the general error magnitude:  0.0

# %%
#!/usr/bin/env python
import psutil
# gives a single float value
psutil.cpu_percent()
# gives an object with many fields
psutil.virtual_memory()
# you can convert that object to a dictionary 
dict(psutil.virtual_memory()._asdict())
# Out:
# {'available': 10643988480,
#  'free': 10643988480,
#  'percent': 37.6,
#  'total': 17065463808,
#  'used': 6421475328}

# %%
def read_mnist(images_path: str, labels_path: str):
    #mnist_path = "data/mnist/"
    #images_path = mnist_path + images_path
    print(images_path)
    with gzip.open(labels_path, 'rb') as labelsFile:
        labels = np.frombuffer(labelsFile.read(), dtype=np.uint8, offset=8)

    with gzip.open(images_path,'rb') as imagesFile:
        length = len(labels)
        # Load flat 28x28 px images (784 px), and convert them to 28x28 px
        features = np.frombuffer(imagesFile.read(), dtype=np.uint8, offset=16) \
                        .reshape(length, 784) \
                        .reshape(length, 28, 28, 1)
        
    return features, labels

# %%
train = {}
test = {}

train['features'], train['labels'] = read_mnist('train-images-idx3-ubyte.gz', 'train-labels-idx1-ubyte.gz')
test['features'], test['labels'] = read_mnist('t10k-images-idx3-ubyte.gz', 't10k-labels-idx1-ubyte.gz')
# Out:
# train-images-idx3-ubyte.gz
# t10k-images-idx3-ubyte.gz

# %%
print('# of training images:', train['features'].shape[0])
print('# of test images:', test['features'].shape[0])
# Out:
# # of training images: 60000
# # of test images: 10000

# %%
def display_image(position):
    image = train['features'][position].squeeze()
    plt.title('Example %d. Label: %d' % (position, train['labels'][position]))
    plt.imshow(image, cmap=plt.cm.gray_r)

# %%
display_image(1)

# %%
train_labels_count = np.unique(train['labels'], return_counts=True)
dataframe_train_labels = pd.DataFrame({'Label':train_labels_count[0], 'Count':train_labels_count[1]})
dataframe_train_labels
# Out:
#    Label  Count
# 0      0   5923
# 1      1   6742
# 2      2   5958
# 3      3   6131
# 4      4   5842
# 5      5   5421
# 6      6   5918
# 7      7   6265
# 8      8   5851
# 9      9   5949

# %%
validation = {}
train['features'], validation['features'], train['labels'], validation['labels'] = train_test_split(train['features'], train['labels'], test_size=0.2, random_state=0)

# %%
print('# of training images:', train['features'].shape[0])
print('# of validation images:', validation['features'].shape[0])
# Out:
# # of training images: 48000
# # of validation images: 12000

# %%
# Pad images with 0s
train['features']      = np.pad(train['features'], ((0,0),(2,2),(2,2),(0,0)), 'constant')
validation['features'] = np.pad(validation['features'], ((0,0),(2,2),(2,2),(0,0)), 'constant')
test['features']       = np.pad(test['features'], ((0,0),(2,2),(2,2),(0,0)), 'constant')
    
print("Updated Image Shape: {}".format(train['features'][0].shape))
# Out:
# Updated Image Shape: (32, 32, 1)

# %% [markdown]
# # HIGH LEVEL - KERAS
# https://colab.research.google.com/drive/1CVm50PGE4vhtB5I_a_yc4h5F-itKOVL9#scrollTo=1zQCBWvZCGon

# %%
model = keras.Sequential()

model.add(layers.Conv2D(filters=6, kernel_size=(3, 3), activation='relu', input_shape=(32,32,1)))
model.add(layers.AveragePooling2D())

model.add(layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
model.add(layers.AveragePooling2D())

model.add(layers.Flatten())

model.add(layers.Dense(units=120, activation='relu'))

model.add(layers.Dense(units=84, activation='relu'))

model.add(layers.Dense(units=10, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 6)         60
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 15, 15, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 16)        880
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 6, 6, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               69240
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 81,194
# Trainable params: 81,194
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# %%
EPOCHS = 3
BATCH_SIZE = 128

# %%
X_train, y_train = train['features'], to_categorical(train['labels'])
X_validation, y_validation = validation['features'], to_categorical(validation['labels'])

train_generator = ImageDataGenerator().flow(X_train, y_train, batch_size=BATCH_SIZE)
validation_generator = ImageDataGenerator().flow(X_validation, y_validation, batch_size=BATCH_SIZE)

# %%
print('# of training images:', train['features'].shape[0])
print('# of validation images:', validation['features'].shape[0])

steps_per_epoch = X_train.shape[0]//BATCH_SIZE
validation_steps = X_validation.shape[0]//BATCH_SIZE

#log_dir = "logs/profile/{}".format(time())
#tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq=1, profile_batch = 3)
# Out:
# # of training images: 48000
# # of validation images: 12000

# %%
import cProfile
stats_filename = "lenet.stats"
cProfile.run("model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=EPOCHS, validation_data=validation_generator, validation_steps=validation_steps, shuffle=True, callbacks=[])", stats_filename)
# Out:
# Epoch 1/3
# 375/375 [==============================] - 18s 48ms/step - loss: 0.0239 - accuracy: 0.9923 - val_loss: 0.0553 - val_accuracy: 0.9837
# Epoch 2/3
# 375/375 [==============================] - 18s 48ms/step - loss: 0.0212 - accuracy: 0.9933 - val_loss: 0.0500 - val_accuracy: 0.9857
# Epoch 3/3
# 375/375 [==============================] - 18s 48ms/step - loss: 0.0165 - accuracy: 0.9944 - val_loss: 0.0474 - val_accuracy: 0.9866

# %%
import pstats
p = pstats.Stats(stats_filename)
p.sort_stats('cumtime')
p.print_stats()
# Out:
# Tue Feb 11 14:44:53 2020    lenet.stats
#
#          23881300 function calls (23404089 primitive calls) in 54.144 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   54.144   54.144 {built-in method builtins.exec}
#         1    0.000    0.000   54.144   54.144 <string>:1(<module>)
#         1    0.000    0.000   54.144   54.144 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:1163(fit_generator)
#       4/1    0.037    0.009   54.144   54.144 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py:41(model_iteration)
#      1125    0.012    0.000   47.948    0.043 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:921(train_on_batch)
#      1125    0.026    0.000   47.838    0.043 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py:197(train_on_batch)
#      1125    0.022    0.000   46.689    0.042 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_eager.py:281(train_on_batch)
#      1125    0.035    0.000   45.084    0.040 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_eager.py:213(_process_single_batch)
#    203511   26.292    0.000   26.294    0.000 {built-in method _pywrap_tensorflow_internal.TFE_Py_FastPathExecute}
#      1125    0.026    0.000   22.098    0.020 c:\python36\lib\site-packages\tensorflow_core\python\eager\backprop.py:935(gradient)
#      1125    0.006    0.000   21.942    0.020 c:\python36\lib\site-packages\tensorflow_core\python\eager\imperative_grad.py:32(imperative_grad)
#      1125    1.534    0.001   21.931    0.019 {built-in method _pywrap_tensorflow_internal.TFE_Py_TapeGradient}
#      1404    0.047    0.000   21.358    0.015 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_eager.py:85(_model_loss)
#     47250    0.149    0.000   20.348    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\backprop.py:116(_gradient_function)
# 12636/1404    0.799    0.000   18.983    0.014 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:703(__call__)
#      1404    0.003    0.000   18.580    0.013 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\sequential.py:252(call)
#      1404    0.110    0.000   18.577    0.013 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\network.py:683(call)
#      1404    0.160    0.000   18.466    0.013 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\network.py:781(_run_internal_graph)
#      2808    0.605    0.000   12.211    0.004 c:\python36\lib\site-packages\tensorflow_core\python\keras\layers\convolutional.py:196(call)
#      2250    0.026    0.000   10.179    0.005 c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_grad.py:569(_Conv2DGrad)
#      2808    0.007    0.000    8.741    0.003 c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_ops.py:1118(__call__)
#      2808    0.005    0.000    8.721    0.003 c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_ops.py:638(__call__)
#      2808    0.007    0.000    8.716    0.003 c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_ops.py:231(__call__)
#      2808    0.017    0.000    8.710    0.003 c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_ops.py:1916(conv2d)
#      2808    0.018    0.000    8.671    0.003 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py:954(conv2d)
#      2808    0.037    0.000    8.624    0.003 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py:1091(conv2d_eager_fallback)
#      4212    0.013    0.000    8.060    0.002 c:\python36\lib\site-packages\tensorflow_core\python\eager\execute.py:33(quick_execute)
#      4212    8.041    0.002    8.041    0.002 {built-in method _pywrap_tensorflow_internal.TFE_Py_Execute}
#      2250    0.010    0.000    5.886    0.003 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py:1136(conv2d_backprop_filter)
#       279    0.002    0.000    4.746    0.017 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:1027(test_on_batch)
#       279    0.006    0.000    4.720    0.017 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py:273(test_on_batch)
#       279    0.004    0.000    4.475    0.016 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_eager.py:322(test_on_batch)
#      2250    0.006    0.000    4.159    0.002 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py:1304(conv2d_backprop_input)
#      1125    0.023    0.000    3.436    0.003 c:\python36\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\optimizer_v2.py:408(apply_gradients)
#      5625    0.013    0.000    3.364    0.001 c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_grad.py:325(_BiasAddGrad)
#      5625    0.011    0.000    3.315    0.001 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py:797(bias_add_grad)
#     87390    0.075    0.000    2.998    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\dispatch.py:177(wrapper)
#      2250    0.017    0.000    2.520    0.001 c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_grad.py:658(_AvgPoolGrad)
#      2250    0.006    0.000    2.336    0.001 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py:376(avg_pool_grad)
#      1125    0.003    0.000    2.225    0.002 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:1885(merge_call)
#      1125    0.007    0.000    2.216    0.002 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:1919(_merge_call)
#      1125    0.085    0.000    2.195    0.002 c:\python36\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\optimizer_v2.py:443(_distributed_apply)
#      7020    0.051    0.000    2.032    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_ops.py:2685(bias_add)
#      2808    0.016    0.000    1.847    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\layers\pooling.py:236(call)
#      7020    0.014    0.000    1.839    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py:711(bias_add)
# 22500/2250    0.045    0.000    1.836    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:2176(_set_trainable_state)
#      2808    0.027    0.000    1.829    0.001 c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_ops.py:3542(avg_pool)
#      2808    0.007    0.000    1.749    0.001 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py:30(avg_pool)
# 305670/66030    0.411    0.000    1.710    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:2250(__setattr__)
#      1404    0.012    0.000    1.693    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_eager.py:42(_eager_metrics_fn)
#     92433    0.244    0.000    1.561    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:1249(internal_convert_to_tensor)
# 42750/22500    0.047    0.000    1.546    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:913(trainable)
#      1404    0.013    0.000    1.508    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:2018(_handle_metrics)
#      2808    0.010    0.000    1.481    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:1992(_handle_per_output_metrics)
#      1404    0.005    0.000    1.458    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py:1049(call_metric_function)
#     11250    0.036    0.000    1.457    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:1489(update)
#      1404    0.006    0.000    1.453    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\metrics.py:162(__call__)
#      1404    0.005    0.000    1.444    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\distribute\distributed_training_utils.py:1107(call_replica_local_fn)
#      1404    0.007    0.000    1.426    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\metrics.py:174(replica_local_fn)
#      4500    0.008    0.000    1.251    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_grad.py:413(_ReluGrad)
#     10962    0.019    0.000    1.248    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py:6082(mat_mul)
#      4500    0.011    0.000    1.242    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py:11122(relu_grad)
#      5616    0.012    0.000    1.177    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\activations.py:178(relu)
#      5616    0.017    0.000    1.165    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\backend.py:4200(relu)
#     84288    0.073    0.000    1.148    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:1127(convert_to_tensor)
#      5616    0.015    0.000    1.148    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py:10912(relu)
#      4212    0.040    0.000    1.143    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\layers\core.py:1041(call)
#     61794    0.201    0.000    1.133    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\nest.py:474(map_structure)
#     85413    0.044    0.000    1.090    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:1187(convert_to_tensor_v2)
#      1404    0.010    0.000    1.077    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\metrics_utils.py:71(decorated)
#     11250    0.012    0.000    1.073    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:2139(_update)
#     11250    0.045    0.000    1.061    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:2144(_update_non_slot)
# 121276/121252    0.280    0.000    1.043    0.000 c:\python36\lib\site-packages\tensorflow_core\python\training\tracking\layer_utils.py:42(filter_empty_layer_containers)
#      1125    0.026    0.000    1.020    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\optimizer_v2.py:601(_prepare)
# 17742/6468    0.060    0.000    1.005    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\network.py:415(__setattr__)
#      1404    0.023    0.000    0.999    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\metrics.py:558(update_state)
#      1125    0.034    0.000    0.942    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\adam.py:153(_prepare_local)
#   2520238    0.485    0.000    0.885    0.000 {built-in method builtins.isinstance}
#     11250    0.043    0.000    0.866    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\optimizer_v2.py:450(apply_grad_to_update_var)
#      3375    0.016    0.000    0.768    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1566(_MatMulGrad)
#      1404    0.008    0.000    0.764    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\losses.py:208(call)
#     15741    0.072    0.000    0.763    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:461(shape_internal)
#     25560    0.135    0.000    0.759    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:646(cast)
#     10116    0.055    0.000    0.745    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:518(value)
#     11250    0.064    0.000    0.736    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\adam.py:184(_resource_apply_dense)
#     14337    0.013    0.000    0.733    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:435(shape)
#      8991    0.007    0.000    0.724    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1788(_dense_var_to_tensor)
#      1404    0.043    0.000    0.724    0.001 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:2320(_standardize_user_data)
#      8991    0.012    0.000    0.717    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1205(_dense_var_to_tensor)
#      1404    0.011    0.000    0.688    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\losses.py:943(categorical_crossentropy)
#      1404    0.012    0.000    0.674    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\losses_utils.py:70(compute_weighted_loss)
#      1404    0.008    0.000    0.623    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\losses\util.py:125(scale_losses_by_sample_weight)
#      1404    0.024    0.000    0.616    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\backend.py:4312(categorical_crossentropy)
#      4500    0.042    0.000    0.608    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_grad.py:137(_SumGrad)
#     15183    0.054    0.000    0.605    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:896(binary_op_wrapper)
#     44160    0.107    0.000    0.596    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:2208(__delattr__)
# 884222/858506    0.347    0.000    0.582    0.000 {built-in method builtins.hasattr}
#     11250    0.017    0.000    0.569    0.000 c:\python36\lib\site-packages\tensorflow_core\python\training\gen_training_ops.py:1481(resource_apply_adam)
#      5616    0.020    0.000    0.564    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\execute.py:231(args_to_matching_eager)
#      1404    0.022    0.000    0.553    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\metrics.py:299(update_state)
# 102360/89724    0.148    0.000    0.543    0.000 c:\python36\lib\site-packages\tensorflow_core\python\training\tracking\base.py:453(_method_wrapper)
#     10116    0.030    0.000    0.526    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:605(_read_variable_op)
#      1404    0.009    0.000    0.524    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:741(on_batch_end)
#      1125    0.043    0.000    0.518    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\generic_utils.py:351(update)
#     67131    0.097    0.000    0.508    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\nest.py:416(pack_sequence_as)
#      1404    0.022    0.000    0.498    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\weights_broadcast_ops.py:136(broadcast_weights)
# 138624/105972    0.071    0.000    0.497    0.000 {built-in method builtins.next}
#     92727    0.272    0.000    0.483    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:6280(__init__)
#      8518    0.465    0.000    0.465    0.000 {method 'acquire' of '_thread.lock' objects}
#     15741    0.020    0.000    0.464    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py:8935(shape)
#      2808    0.004    0.000    0.460    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\execute.py:261(<listcomp>)
#      8712    0.034    0.000    0.453    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:922(r_binary_op_wrapper)
#     88320    0.089    0.000    0.445    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:2184(_obj_reference_counts)
#     40746    0.026    0.000    0.445    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\constant_op.py:164(constant)
#      6183    0.040    0.000    0.436    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:1095(div_no_nan)
#      2808    0.026    0.000    0.424    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:219(_call_batch_hook)
#     40746    0.051    0.000    0.419    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\constant_op.py:230(_constant_impl)
#      4254    0.009    0.000    0.416    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:407(metrics)
#      1125    0.019    0.000    0.409    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1299(_DivNoNanGrad)
#      4254    0.034    0.000    0.407    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:3223(_get_metrics_from_layers)
#    178976    0.231    0.000    0.400    0.000 c:\python36\lib\abc.py:178(__instancecheck__)
#      2808    0.005    0.000    0.385    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\losses_utils.py:58(reduce_weighted_loss)
#       587    0.002    0.000    0.383    0.001 c:\python36\lib\site-packages\ipykernel\iostream.py:311(flush)
#      3933    0.028    0.000    0.381    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:762(assign_add)
#      1995    0.006    0.000    0.376    0.000 c:\python36\lib\threading.py:533(wait)
#     61794    0.044    0.000    0.373    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\nest.py:535(<listcomp>)
#       599    0.003    0.000    0.371    0.001 c:\python36\lib\threading.py:263(wait)
#     12645    0.028    0.000    0.364    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:1530(reduce_sum)
# 62463/49827    0.114    0.000    0.361    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:2326(_gather_children_attribute)
#      2808    0.006    0.000    0.359    0.000 c:\python36\lib\site-packages\numpy\lib\function_base.py:3414(median)
#      6745    0.015    0.000    0.356    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\sequential.py:116(layers)
#     40746    0.282    0.000    0.353    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\constant_op.py:68(convert_to_eager_tensor)
#      2808    0.010    0.000    0.353    0.000 c:\python36\lib\site-packages\numpy\lib\function_base.py:3354(_ureduce)
#     10116    0.014    0.000    0.344    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_resource_variable_ops.py:544(read_variable_op)
#      6745    0.011    0.000    0.340    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\network.py:502(layers)
#      1404    0.006    0.000    0.338    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\metrics_utils.py:102(decorated)
#      9561    0.019    0.000    0.336    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\deprecation.py:473(new_func)
#     73323    0.040    0.000    0.333    0.000 {built-in method builtins.all}
#      5341    0.008    0.000    0.329    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\sequential.py:128(dynamic)
#     12636    0.035    0.000    0.329    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:1763(_maybe_cast_inputs)
#    216910    0.108    0.000    0.329    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\nest.py:231(flatten)
#     12636    0.087    0.000    0.326    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:1942(_set_mask_metadata)
#     11529    0.018    0.000    0.324    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:59(reshape)
#      1404    0.025    0.000    0.311    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:669(_slice_helper)
# 68610/52284    0.026    0.000    0.310    0.000 c:\python36\lib\contextlib.py:80(__enter__)
#      2808    0.036    0.000    0.308    0.000 c:\python36\lib\site-packages\numpy\lib\function_base.py:3503(_median)
#      1125    0.018    0.000    0.305    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1272(_RealDivGrad)
#    127287    0.189    0.000    0.299    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:6367(enter_eager_name_scope)
#     19116    0.020    0.000    0.297    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py:6665(mul)
#      1404    0.014    0.000    0.291    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\layers\core.py:574(call)
#     11529    0.017    0.000    0.283    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py:8026(reshape)
#     21927    0.018    0.000    0.281    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_conversion_registry.py:50(_default_conversion_function)
#    132480    0.120    0.000    0.281    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\object_identity.py:116(__getitem__)
#     92727    0.069    0.000    0.278    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:6308(__enter__)
#      1413    0.005    0.000    0.275    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:173(make_logs)
#      2838    0.006    0.000    0.269    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:417(metrics_names)
#    106557    0.064    0.000    0.267    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:5861(get_default_graph)
#      4216    0.006    0.000    0.266    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:437(run_eagerly)
#    177162    0.083    0.000    0.265    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\object_identity.py:177(add)
#      1404    0.021    0.000    0.263    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\weights_broadcast_ops.py:63(assert_broadcastable)
#    177162    0.110    0.000    0.263    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\object_identity.py:171(__contains__)
#     40734    0.078    0.000    0.260    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\tf_utils.py:322(is_symbolic_tensor)
#     12636    0.043    0.000    0.256    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:1982(_collect_input_masks)
#     25272    0.027    0.000    0.255    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\tf_utils.py:315(are_all_symbolic_tensors)
#      1404    0.006    0.000    0.253    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py:1267(cast_to_model_input_dtypes)
#      4779    0.014    0.000    0.251    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:176(identity)
#     12645    0.015    0.000    0.243    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py:11120(_sum)
#     58203    0.063    0.000    0.232    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribution_strategy_context.py:78(_get_per_thread_mode)
#      1404    0.011    0.000    0.231    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\metrics.py:2763(categorical_accuracy)
#      1125    0.005    0.000    0.230    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\network.py:540(trainable_weights)
#      1404    0.004    0.000    0.226    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\metrics.py:361(result)
#    177979    0.143    0.000    0.224    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\context.py:1601(executing_eagerly)
#    216910    0.081    0.000    0.221    0.000 c:\python36\lib\site-packages\tensorflow_core\python\pywrap_tensorflow_internal.py:2619(Flatten)
#     50544    0.016    0.000    0.218    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\tf_utils.py:316(<genexpr>)
#     59850    0.080    0.000    0.216    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\dtypes.py:144(is_floating)
#    497484    0.132    0.000    0.216    0.000 {built-in method builtins.getattr}
#     35112    0.036    0.000    0.211    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:1030(shape)
#      1404    0.013    0.000    0.209    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\clip_ops.py:36(clip_by_value)
# 68610/52284    0.076    0.000    0.205    0.000 c:\python36\lib\contextlib.py:86(__exit__)
#    106557    0.116    0.000    0.203    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:5455(get_default)
# 14040/1404    0.026    0.000    0.202    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:990(losses)
#     26688    0.049    0.000    0.201    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_shape.py:743(__init__)
#      2250    0.006    0.000    0.199    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1399(_MaximumMinimumGrad)
#     17973    0.030    0.000    0.198    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\nest.py:384(_packed_nest_with_indices)
#      1404    0.009    0.000    0.194    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\losses_utils.py:52(_num_elements)
#      2250    0.007    0.000    0.192    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1389(_MaximumMinimumGradInputOnly)
#      3945    0.017    0.000    0.186    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:786(_lazy_read)
#      2808    0.004    0.000    0.184    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:515(size)
#     11250    0.010    0.000    0.183    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:2087(colocate_vars_with)
#      2808    0.015    0.000    0.180    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:547(size_internal)
#     11250    0.016    0.000    0.180    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:2054(__enter__)
#    575124    0.129    0.000    0.179    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\object_identity.py:48(__hash__)
#     34560    0.067    0.000    0.179    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:6430(__enter__)
# 14040/1404    0.023    0.000    0.178    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:1137(_clear_losses)
#     26991    0.031    0.000    0.175    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:5111(device)
#     23616    0.013    0.000    0.174    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:5217(colocate_with)
#    354324    0.119    0.000    0.173    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\object_identity.py:168(_wrap_key)
#     50064    0.035    0.000    0.166    0.000 c:\python36\lib\_collections_abc.py:657(get)
#     12636    0.030    0.000    0.165    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer_utils.py:442(autocast_context_manager)
#    335488    0.164    0.000    0.164    0.000 c:\python36\lib\_weakrefset.py:70(__contains__)
#      1125    0.004    0.000    0.162    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\variables.py:1077(_run_op)
#     23616    0.033    0.000    0.160    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:5194(_colocate_with_for_gradient)
#      9558    0.010    0.000    0.160    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:1202(_mul_dispatch)
#     84665    0.069    0.000    0.159    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\object_identity.py:119(__setitem__)
#     27530    0.027    0.000    0.159    0.000 {built-in method builtins.any}
#     34839    0.019    0.000    0.157    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\nest.py:164(_yield_value)
#      4212    0.017    0.000    0.155    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\losses\util.py:35(squeeze_or_expand_dimensions)
#     38286    0.022    0.000    0.153    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:1146(metrics)
#     68610    0.044    0.000    0.152    0.000 c:\python36\lib\contextlib.py:157(helper)
#      1404    0.004    0.000    0.148    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:870(strided_slice)
#      4212    0.010    0.000    0.148    0.000 c:\python36\lib\site-packages\numpy\core\fromnumeric.py:2664(prod)
#      3945    0.010    0.000    0.145    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\variables.py:256(__call__)
#      2250    0.008    0.000    0.145    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_grad.py:36(_safe_shape_div)
#      1404    0.003    0.000    0.144    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py:10208(strided_slice)
#     10450    0.127    0.000    0.141    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      1125    0.005    0.000    0.140    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\optimizer_v2.py:618(_prepare_local)
#     22500    0.027    0.000    0.140    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\variable_scope.py:2647(variable_creator_scope)
#      1404    0.003    0.000    0.140    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:2466(ones_like)
#    216910    0.140    0.000    0.140    0.000 {built-in method _pywrap_tensorflow_internal.Flatten}
#    243576    0.100    0.000    0.139    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\dtypes.py:690(as_dtype)
#      6741    0.009    0.000    0.139    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py:2180(cast)
#      4212    0.021    0.000    0.138    0.000 c:\python36\lib\site-packages\numpy\core\fromnumeric.py:69(_wrapreduction)
#     34839    0.043    0.000    0.138    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\nest.py:169(_yield_sorted_items)
#      1404    0.006    0.000    0.137    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:2529(ones_like_impl)
#     34875    0.070    0.000    0.136    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\backprop.py:100(get_attr)
#      3945    0.012    0.000    0.135    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1805(__init__)
#     65466    0.058    0.000    0.134    0.000 c:\python36\lib\site-packages\numpy\core\numerictypes.py:365(issubdtype)
#    154650    0.067    0.000    0.133    0.000 c:\python36\lib\site-packages\tensorflow_core\python\training\tracking\layer_utils.py:27(is_layer)
#     14061    0.022    0.000    0.133    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:309(variable_accessed)
#     61794    0.034    0.000    0.131    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\nest.py:531(<listcomp>)
#      3375    0.015    0.000    0.131    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1160(_MulGrad)
#      1404    0.009    0.000    0.130    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py:8133(reshape_eager_fallback)
#    132538    0.113    0.000    0.130    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\object_identity.py:159(__init__)
#      1404    0.003    0.000    0.127    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\losses_utils.py:37(_safe_mean)
#     26688    0.021    0.000    0.126    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_shape.py:776(<listcomp>)
# 193500/189000    0.102    0.000    0.125    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\optimizer_v2.py:538(__getattribute__)
#      2529    0.018    0.000    0.121    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:989(_truediv_python3)
#      1125    0.007    0.000    0.120    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_grad.py:282(_SoftmaxGrad)
#      5904    0.007    0.000    0.120    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py:7907(real_div)
#     92142    0.070    0.000    0.119    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\dtypes.py:260(__eq__)
#      7029    0.008    0.000    0.119    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py:11052(sub)
#      1125    0.007    0.000    0.117    0.000 c:\python36\lib\site-packages\tensorflow_core\python\training\tracking\layer_utils.py:62(gather_trainable_weights)
#      1125    0.011    0.000    0.116    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_grad.py:607(_ReshapeGrad)
#    403036    0.116    0.000    0.116    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\context.py:654(executing_eagerly)
#     71604    0.037    0.000    0.116    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_shape.py:702(as_dimension)
#     34560    0.042    0.000    0.115    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:6451(__exit__)
#     17973    0.073    0.000    0.114    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\nest.py:117(_sequence_like)
#    188416    0.060    0.000    0.113    0.000 {method 'add' of 'set' objects}
#     44160    0.019    0.000    0.112    0.000 c:\python36\lib\_collections_abc.py:664(__contains__)
#     26991    0.028    0.000    0.112    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\context.py:1669(device)
#      2529    0.010    0.000    0.111    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:1191(_add_dispatch)
#     11232    0.041    0.000    0.110    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:1778(f)
#    169977    0.085    0.000    0.110    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:912(dtype)
#     10131    0.016    0.000    0.109    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:944(trainable_weights)
#      1125    0.001    0.000    0.108    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1436(_MaximumGrad)
#     68610    0.090    0.000    0.108    0.000 c:\python36\lib\contextlib.py:60(__init__)
#     92727    0.072    0.000    0.108    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:6355(__exit__)
# 11250/1125    0.023    0.000    0.105    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:2162(_get_trainable_state)
#      2808    0.005    0.000    0.104    0.000 c:\python36\lib\site-packages\numpy\core\fromnumeric.py:646(partition)
#    220800    0.074    0.000    0.103    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\object_identity.py:113(_wrap_key)
#      2250    0.002    0.000    0.103    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:2366(zeros_like)
#      3945    0.029    0.000    0.103    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:320(__init__)
#      4212    0.003    0.000    0.102    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:1110(stack)
#      2250    0.014    0.000    0.101    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:2438(zeros_like_impl)
#      6183    0.007    0.000    0.101    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py:3505(div_no_nan)
#      1405    0.007    0.000    0.101    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:1423(_check_call_args)
#      4707    0.002    0.000    0.101    0.000 c:\python36\lib\threading.py:1062(_wait_for_tstate_lock)
#      1404    0.004    0.000    0.100    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\activations.py:43(softmax)
# 75099/62463    0.012    0.000    0.100    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:2336(<genexpr>)
#     25272    0.055    0.000    0.100    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:1996(_call_arg_was_passed)
#    151128    0.049    0.000    0.099    0.000 c:\python36\lib\site-packages\tensorflow_core\python\pywrap_tensorflow_internal.py:2502(IsSequence)
#      2808    0.004    0.000    0.099    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:125(argmax)
#    161862    0.066    0.000    0.098    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\dtypes.py:100(base_dtype)
#         4    0.000    0.000    0.097    0.024 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\data_utils.py:654(stop)
#         4    0.000    0.000    0.096    0.024 c:\python36\lib\threading.py:1024(join)
#     44160    0.035    0.000    0.096    0.000 c:\python36\lib\site-packages\tensorflow_core\python\training\tracking\data_structures.py:92(sticky_attribute_assignment)
#      2808    0.004    0.000    0.095    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:141(argmax_v2)
#     23625    0.017    0.000    0.094    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:194(_require_cross_replica_or_default_context_extended)
#      1405    0.005    0.000    0.093    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\tf_inspect.py:238(getfullargspec)
#      1125    0.001    0.000    0.093    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1442(_MinimumGrad)
#     11262    0.022    0.000    0.093    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:2392(_dedup_weights)
#     47250    0.058    0.000    0.092    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\registry.py:82(lookup)
#      2808    0.004    0.000    0.091    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py:909(arg_max)
#      1125    0.012    0.000    0.091    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\adam.py:142(_create_slots)
#     26991    0.065    0.000    0.091    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\context.py:1502(__enter__)
#      2808    0.090    0.000    0.090    0.000 {method 'partition' of 'numpy.ndarray' objects}
#    254574    0.088    0.000    0.088    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\context.py:671(scope_name)
#     35409    0.045    0.000    0.085    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\dtypes.py:240(is_compatible_with)
#      2808    0.031    0.000    0.084    0.000 c:\python36\lib\site-packages\numpy\lib\utils.py:1116(_median_nancheck)
#    575124    0.083    0.000    0.083    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\object_identity.py:33(__init__)
#      1405    0.018    0.000    0.083    0.000 c:\python36\lib\inspect.py:1052(getfullargspec)
#    213490    0.062    0.000    0.083    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\object_identity.py:40(__eq__)
#     25272    0.024    0.000    0.083    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:5070(_enable_auto_casting_variables)
#     15462    0.011    0.000    0.082    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribution_strategy_context.py:199(has_strategy)
#      1125    0.004    0.000    0.082    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:1465(batch_reduce_to)
#     47754    0.034    0.000    0.081    0.000 c:\python36\lib\site-packages\tensorflow_core\python\training\tracking\tracking.py:417(wrapped)
#      1125    0.008    0.000    0.081    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_grad.py:632(_LogGrad)
#     16866    0.008    0.000    0.081    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribution_strategy_context.py:179(get_strategy)
#      3654    0.005    0.000    0.079    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py:6260(maximum)
#     57564    0.059    0.000    0.078    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_shape.py:184(__init__)
#      1404    0.002    0.000    0.077    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\network.py:440(stateful)
#    168858    0.076    0.000    0.076    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:1082(graph)
#      2808    0.002    0.000    0.074    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:586(rank)
#     16020    0.017    0.000    0.074    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:918(numpy)
#     73074    0.074    0.000    0.074    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\context.py:474(ensure_initialized)
#     12645    0.011    0.000    0.074    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:1442(_ReductionDims)
#      2808    0.014    0.000    0.073    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_shape.py:907(merge_with)
#      3988    0.011    0.000    0.073    0.000 c:\python36\lib\site-packages\numpy\core\fromnumeric.py:3014(mean)
#      2354    0.006    0.000    0.073    0.000 c:\python36\lib\site-packages\ipykernel\iostream.py:342(write)
#      2808    0.012    0.000    0.073    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:620(rank_internal)
#      1404    0.004    0.000    0.073    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_ops.py:2931(softmax)
#     11520    0.012    0.000    0.072    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_util.py:767(constant_value)
#      1125    0.001    0.000    0.072    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:1483(_batch_reduce_to)
#      3933    0.005    0.000    0.071    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_resource_variable_ops.py:30(assign_add_variable_op)
#      1404    0.011    0.000    0.071    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:2542(ones)
#      1125    0.002    0.000    0.071    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\network.py:1613(_assert_weights_created)
#     34560    0.030    0.000    0.070    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\backend.py:735(name_scope)
#      1125    0.006    0.000    0.070    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:1485(<listcomp>)
#     22500    0.027    0.000    0.070    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\optimizer_v2.py:567(add_slot)
#      4500    0.005    0.000    0.070    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py:11261(tile)
#    684476    0.070    0.000    0.070    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\context.py:1576(context_safe)
#    130932    0.043    0.000    0.069    0.000 c:\python36\lib\site-packages\numpy\core\numerictypes.py:293(issubclass_)
#     12375    0.015    0.000    0.069    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:3424(conj)
#      5616    0.004    0.000    0.069    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\constant_op.py:283(_constant_tensor_conversion_function)
#      4116    0.053    0.000    0.069    0.000 c:\python36\lib\site-packages\ipykernel\iostream.py:180(schedule)
#      1404    0.005    0.000    0.068    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\nn_ops.py:2852(_softmax)
#      2808    0.016    0.000    0.067    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\confusion_matrix.py:33(remove_squeezable_dimensions)
#      2250    0.005    0.000    0.067    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py:489(shape_n)
#     11250    0.017    0.000    0.065    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:1438(reduce_to)
#      5904    0.014    0.000    0.064    0.000 c:\python36\lib\site-packages\tensorflow_core\python\compat\compat.py:49(forward_compatible)
#      1404    0.002    0.000    0.064    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py:360(_get_next_batch)
#      4779    0.005    0.000    0.064    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py:6801(neg)
#     11250    0.014    0.000    0.063    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:2063(__exit__)
#     26991    0.045    0.000    0.063    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\context.py:1536(__exit__)
#      1404    0.008    0.000    0.062    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py:1227(cast_if_floating_dtype_and_mismatch)
#      2250    0.005    0.000    0.062    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py:9015(shape_n)
#      2529    0.004    0.000    0.062    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py:513(add_v2)
#      2250    0.007    0.000    0.061    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:434(pow)
#      1408    0.014    0.000    0.060    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\data_utils.py:767(get)
#      3988    0.023    0.000    0.060    0.000 c:\python36\lib\site-packages\numpy\core\_methods.py:58(_mean)
# 2810/1405    0.009    0.000    0.058    0.000 c:\python36\lib\inspect.py:2146(_signature_from_callable)
#     11250    0.010    0.000    0.058    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:245(_require_strategy_scope_extended)
#    106557    0.046    0.000    0.057    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:5268(get_default)
#      2250    0.006    0.000    0.056    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\math_ops.py:1152(floordiv)
#      1404    0.002    0.000    0.056    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py:11343(softmax)
#    614436    0.055    0.000    0.055    0.000 {built-in method builtins.id}
#      2808    0.018    0.000    0.055    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py:453(standardize_input_data)
#     10152    0.014    0.000    0.053    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:5534(init_scope)
#     34560    0.016    0.000    0.053    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\ops.py:6444(<lambda>)
#     28116    0.020    0.000    0.053    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\context.py:1581(ensure_initialized)
#     11250    0.006    0.000    0.051    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:541(scope)
#      2808    0.017    0.000    0.051    0.000 c:\python36\lib\site-packages\numpy\core\numeric.py:1620(moveaxis)
#      5904    0.009    0.000    0.051    0.000 c:\python36\lib\site-packages\tensorflow_core\python\compat\compat.py:40(_get_forward_compatibility_date)
# ...
#      1404    0.001    0.000    0.001    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:2973(output_name)
#      1404    0.001    0.000    0.001    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:3183(skip_target_weights)
#      1404    0.001    0.000    0.001    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\backend_config.py:32(epsilon)
#      1416    0.001    0.000    0.001    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:3051(output_loss_metric)
#      5620    0.001    0.000    0.001    0.000 c:\python36\lib\inspect.py:2456(annotation)
#      1404    0.001    0.000    0.001    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\network.py:808(<listcomp>)
#      1404    0.001    0.000    0.001    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_eager.py:147(<listcomp>)
#      2808    0.001    0.000    0.001    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:2544(<genexpr>)
#      1404    0.001    0.000    0.001    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:2969(output)
#      1125    0.001    0.000    0.001    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\tape.py:38(__init__)
#      1404    0.001    0.000    0.001    0.000 {method 'join' of 'str' objects}
#      2808    0.001    0.000    0.001    0.000 c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py:1111(<listcomp>)
#      2808    0.001    0.000    0.001    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py:595(<listcomp>)
#      1404    0.001    0.000    0.001    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_spec.py:75(shape)
#      1125    0.001    0.000    0.001    0.000 c:\python36\lib\enum.py:597(value)
#      4807    0.001    0.000    0.001    0.000 {method '__exit__' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#      1404    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:1666(<listcomp>)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:120(set_callback_parameters)
#      1404    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\distribute\distributed_training_utils.py:440(is_tpu_strategy)
#      1125    0.000    0.000    0.000    0.000 c:\python36\lib\enum.py:515(__new__)
#      1405    0.000    0.000    0.000    0.000 c:\python36\lib\inspect.py:2757(return_annotation)
#      2808    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:2546(<genexpr>)
#       599    0.000    0.000    0.000    0.000 c:\python36\lib\threading.py:248(_release_save)
#      1428    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_shape.py:814(dims)
#      1404    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:3067(sample_weight_mode)
#      2250    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:463(on_batch_begin)
#      1404    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\losses.py:970(<lambda>)
#        24    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\training\tracking\data_structures.py:187(layers)
#         6    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:952(non_trainable_weights)
#      1348    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#      1404    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py:2007(_get_call_arg_value)
#      1404    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\distribute\distribute_lib.py:2163(_num_replicas_in_sync)
#      1404    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#      1404    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#      1404    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#      1405    0.000    0.000    0.000    0.000 c:\python36\lib\inspect.py:2753(parameters)
#      1125    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:466(on_batch_end)
#         4    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#        24    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\training\tracking\data_structures.py:174(_layers)
#      1125    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\training\tracking\layer_utils.py:81(<listcomp>)
#        24    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\training\tracking\data_structures.py:714(_values)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\data_utils.py:711(__init__)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\threading.py:757(__init__)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\data_utils.py:596(__init__)
#       558    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:533(on_test_batch_end)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\queue.py:27(__init__)
#       558    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:519(on_test_batch_begin)
#        12    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_shape.py:1102(assert_is_compatible_with)
#         6    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\generic_utils.py:326(__init__)
#        12    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\backend.py:1216(dtype)
#         3    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:284(on_epoch_end)
#         8    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\utils\data_utils.py:99(is_generator_or_sequence)
#         3    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:269(on_epoch_begin)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py:435(convert_to_generator_like)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\threading.py:512(set)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py:378(_validate_arguments)
#         8    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\util\tf_inspect.py:380(isgenerator)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py:546(_get_num_samples_or_steps)
#         7    0.000    0.000    0.000    0.000 c:\python36\lib\threading.py:357(notify_all)
#         8    0.000    0.000    0.000    0.000 c:\python36\lib\threading.py:1230(current_thread)
#        12    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:204(<lambda>)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\monitoring.py:332(get_cell)
#         8    0.000    0.000    0.000    0.000 <string>:2(getvalue)
#         3    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:783(on_epoch_end)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\multiprocessing\synchronize.py:95(__enter__)
#         3    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:666(on_epoch_end)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:201(_reset_batch_timing)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\monitoring.py:133(get_cell)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:245(_call_begin_hook)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:254(_call_end_hook)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:708(__init__)
#         6    0.000    0.000    0.000    0.000 {method 'isatty' of '_io._IOBase' objects}
#         6    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py:138(finalize)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py:119(__init__)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py:525(_make_execution_function)
#         4    0.000    0.000    0.000    0.000 {method '__enter__' of '_multiprocessing.SemLock' objects}
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\threading.py:966(_stop)
#         1    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.TFE_MonitoringGetCellBoolGauge1}
#         6    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py:126(create)
#         6    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:449(__init__)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\_weakrefset.py:81(add)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:193(__init__)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\multiprocessing\synchronize.py:98(__exit__)
#         4    0.000    0.000    0.000    0.000 <string>:8(setvalue)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\threading.py:727(_newname)
#         3    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:376(on_test_begin)
#         8    0.000    0.000    0.000    0.000 c:\python36\lib\inspect.py:200(isgenerator)
#         3    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:386(on_test_end)
#         4    0.000    0.000    0.000    0.000 {method '__exit__' of '_multiprocessing.SemLock' objects}
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\threading.py:1136(daemon)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\monitoring.py:300(set)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:2835(_maybe_load_initial_epoch_from_ckpt)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:356(on_train_begin)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py:74(__init__)
#         3    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:645(on_epoch_begin)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:641(__init__)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\queue.py:199(_init)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:366(on_train_end)
#         6    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\metrics.py:209(<listcomp>)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training.py:1765(_get_callback_model)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:209(set_params)
#         3    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py:1832(should_run_validation)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:718(on_train_begin)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\threading.py:1120(daemon)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\copy.py:66(copy)
#         6    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\ipykernel\iostream.py:293(closed)
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\multiprocessing\sharedctypes.py:204(get_lock)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:214(set_model)
#        12    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         4    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py:430(<genexpr>)
#        12    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:416(__iter__)
#         2    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:457(set_params)
#         1    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.TFE_MonitoringBoolGaugeCellSet}
#         6    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:587(on_test_begin)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\eager\monitoring.py:292(__init__)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:154(<listcomp>)
#         4    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:597(on_test_end)
#         2    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:460(set_model)
#         3    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:469(on_epoch_begin)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:779(on_train_begin)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:195(<listcomp>)
#         2    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:577(on_train_end)
#         1    0.000    0.000    0.000    0.000 c:\python36\lib\site-packages\tensorflow_core\python\keras\callbacks.py:567(on_train_begin)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
score = model.evaluate(test['features'], to_categorical(test['labels']))
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test loss: 0.05474768261319259
# Test accuracy: 0.9823

# %% [markdown]
# # LOW LEVEL - TF.VARIABLE
# https://colab.research.google.com/drive/1kV3Jpxzup63GfJB1FGKxTSKd6Ek8J3sA#scrollTo=d669sWrHlP0g
# <br>Inspired by:<br>
# https://github.com/udacity/CarND-LeNet-Lab/blob/master/LeNet-Lab-Solution.ipynb

# %% [markdown]
# Architecture
# Convolutional #1 outputs 28x28x6
#
# Activation any activation function, we will relu
# Pooling #1 The output shape should be 14x14x6.
#
# Convolutional #2 outputs 10x10x16.
#
# Activation any activation function, we will relu
# Pooling #2 outputs 5x5x16.
#
# Flatten Flatten the output shape of the final pooling layer
# Fully Connected #1 outputs 120
#
# Activation any activation function, we will relu
# Fully Connected #2 outputs 84
#
# Activation any activation function, we will relu
# Fully Connected (Logits) #3 outpute 10

# %%
n_classes = 10

def LeNet(x):    
    # Arguments used for tf.truncated_normal, randomly defines variables for the weights and biases for each layer
    mu = 0
    sigma = 0.1    
    
    weights = {
        # The shape of the filter weight is (height, width, input_depth, output_depth)
        'conv1': tf.Variable(tf.truncated_normal(shape=(5, 5, 1, 6), mean = mu, stddev = sigma)),
        'conv2': tf.Variable(tf.truncated_normal(shape=(5, 5, 6, 16), mean = mu, stddev = sigma)),
        'fl1': tf.Variable(tf.truncated_normal(shape=(5 * 5 * 16, 120), mean = mu, stddev = sigma)),
        'fl2': tf.Variable(tf.truncated_normal(shape=(120, 84), mean = mu, stddev = sigma)),
        'out': tf.Variable(tf.truncated_normal(shape=(84, n_classes), mean = mu, stddev = sigma))
    }

    biases = {
        # The shape of the filter bias is (output_depth,)
        'conv1': tf.Variable(tf.zeros(6)),
        'conv2': tf.Variable(tf.zeros(16)),
        'fl1': tf.Variable(tf.zeros(120)),
        'fl2': tf.Variable(tf.zeros(84)),
        'out': tf.Variable(tf.zeros(n_classes))
    }

    # Layer 1: Convolutional. Input = 32x32x1. Output = 28x28x6.
    conv1 = tf.nn.conv2d(x, weights['conv1'], strides=[1, 1, 1, 1], padding='VALID')
    conv1 = tf.nn.bias_add(conv1, biases['conv1'])
    # Activation.
    conv1 = tf.nn.relu(conv1)
    # Pooling. Input = 28x28x6. Output = 14x14x6.
    conv1 = tf.nn.avg_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')
    
    # Layer 2: Convolutional. Output = 10x10x16.
    conv2 = tf.nn.conv2d(conv1, weights['conv2'], strides=[1, 1, 1, 1], padding='VALID')
    conv2 = tf.nn.bias_add(conv2, biases['conv2'])
    # Activation.
    conv2 = tf.nn.relu(conv2)
    # Pooling. Input = 10x10x16. Output = 5x5x16.
    conv2 = tf.nn.avg_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # Flatten. Input = 5x5x16. Output = 400.
    fl0 = flatten(conv2)
    
    # Layer 3: Fully Connected. Input = 400. Output = 120.
    fl1 = tf.add(tf.matmul(fl0, weights['fl1']), biases['fl1'])
    # Activation.
    fl1 = tf.nn.relu(fl1)
    
    # Layer 4: Fully Connected. Input = 120. Output = 84.
    fl2 = tf.add(tf.matmul(fl1, weights['fl2']), biases['fl2'])
    # Activation.
    fl2 = tf.nn.relu(fl2)

    # Layer 5: Fully Connected. Input = 84. Output = 10.
    logits = tf.add(tf.matmul(fl2, weights['out']), biases['out'])
                 
    return logits

# %% [markdown]
# Features and Labels<br>
# x is a placeholder for a batch of input images.<br>
# y is a placeholder for a batch of output labels.

# %% [markdown]
# ### Migration
# https://www.tensorflow.org/guide/migrate#low-level_variables_operator_execution

# %% [markdown]
# # LOW LEVEL GUIDE - 2.0
# https://www.juliabloggers.com/tensorflow-2-0-building-simple-classifier-using-low-level-apis/

# %%
x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, n_classes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_shape.py in __init__(self, dims)
#     769       try:
# --> 770         dims_iter = iter(dims)
#     771       except TypeError:
#
# TypeError: 'DType' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\python36\lib\site-packages\tensorflow_core\python\eager\execute.py in make_shape(v, arg_name)
#     205   try:
# --> 206     shape = tensor_shape.as_shape(v)
#     207   except TypeError as e:
#
# c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_shape.py in as_shape(shape)
#    1215   else:
# -> 1216     return TensorShape(shape)
#    1217
#
# c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_shape.py in __init__(self, dims)
#     772         # Treat as a singleton dimension
# --> 773         self._dims = [as_dimension(dims)]
#     774       else:
#
# c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_shape.py in as_dimension(value)
#     717   else:
# --> 718     return Dimension(value)
#     719
#
# c:\python36\lib\site-packages\tensorflow_core\python\framework\tensor_shape.py in __init__(self, value)
#     190     elif isinstance(value, dtypes.DType):
# --> 191       raise TypeError("Cannot convert %s to Dimension" % value)
#     192     else:
#
# TypeError: Cannot convert <dtype: 'float32'> to Dimension
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-f3bbcca22dc1> in <module>()
#       1 from keras.backend import placeholder
# ----> 2 x = placeholder(tf.float32, (None, 32, 32, 1))
#       3 y = placeholder(tf.int32, (None))
#       4 one_hot_y = tf.one_hot(y, n_classes)
#
# c:\python36\lib\site-packages\keras\backend\tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
#      73         if _SYMBOLIC_SCOPE.value:
#      74             with get_graph().as_default():
# ---> 75                 return func(*args, **kwargs)
#      76         else:
#      77             return func(*args, **kwargs)
#
# c:\python36\lib\site-packages\keras\backend\tensorflow_backend.py in placeholder(shape, ndim, dtype, sparse, name)
#     734         dtype = floatx()
#     735     x = tf_keras_backend.placeholder(
# --> 736         shape=shape, ndim=ndim, dtype=dtype, sparse=sparse, name=name)
#     737     if shape is None:
#     738         if ndim is not None:
#
# c:\python36\lib\site-packages\tensorflow_core\python\keras\backend.py in placeholder(shape, ndim, dtype, sparse, name, ragged)
#    1050           name=name)
#    1051     else:
# -> 1052       x = array_ops.placeholder(dtype, shape=shape, name=name)
#    1053   return x
#    1054
#
# c:\python36\lib\site-packages\tensorflow_core\python\ops\array_ops.py in placeholder(dtype, shape, name)
#    2628                        "eager execution.")
#    2629
# -> 2630   return gen_array_ops.placeholder(dtype=dtype, shape=shape, name=name)
#    2631
#    2632
#
# c:\python36\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py in placeholder(dtype, shape, name)
#    6666   if shape is None:
#    6667     shape = None
# -> 6668   shape = _execute.make_shape(shape, "shape")
#    6669   _, _, _op = _op_def_lib._apply_op_helper(
#    6670         "Placeholder", dtype=dtype, shape=shape, name=name)
#
# c:\python36\lib\site-packages\tensorflow_core\python\eager\execute.py in make_shape(v, arg_name)
#     206     shape = tensor_shape.as_shape(v)
#     207   except TypeError as e:
# --> 208     raise TypeError("Error converting %s to a TensorShape: %s." % (arg_name, e))
#     209   except ValueError as e:
#     210     raise ValueError("Error converting %s to a TensorShape: %s." % (arg_name,
#
# TypeError: Error converting shape to a TensorShape: Cannot convert <dtype: 'float32'> to Dimension.
